# %%
# k crossover d，close > ema 8, ema 8 > ema 18, ema 18 > 38, take profit atr, stop loss atr
# Variables :
# time - 15m, 1h
# start time - 1609459200000, 1641028611000, 1672564611000, 1654045261000, 1651366861000 (2021, 2022, 2023)
# start_time = 1635743450000 2021/11 end_time = 1654060250000 2022/6 BEAR

# %%
# ! conda install -c conda-forge ta --yes

# %%
import requests
import pandas as pd
import ta
import datetime as dt
import numpy as np
import time
import itertools
import os

# %%
from binance.client import Client
from dotenv import load_dotenv

# Get the path to the current directory
current_directory = os.getcwd()

# Specify the path to the .env file relative to the current directory
dotenv_path = os.path.join(current_directory, '.env')

# Load the environment variables from the .env file
load_dotenv(dotenv_path)

api_key = os.getenv('API_KEY')
api_secret = os.getenv('SECRET_KEY')

client = Client(api_key, api_secret, testnet = False)

# %%
# start_time_arr = [1672531200000, 1651366861000]

interval_arr = ['1h', '15m']

# how kd is crossed
kd_dir_arr = ['Any', 'Up']

sl_atr_arr = [1, 3, 5, 7]

tp_atr_arr = [3, 5, 9, 12]

# stop loss determine candlestick
sl_det_arr = ['Close']

# %%
timezone = 8
# symbol = 'nearusdt'
symbol_arr = ['ethusdt', 'nearusdt', 'ftmusdt', 'sandusdt', 'woousdt', 'dydxusdt', 'atomusdt']
start_time_d = 1635743450000
end_time = round(time.time() * 1000)
# end_time = 1654060250000 
# step between timestamps in milliseconds
step = 1000

# %%
dataframes = {}
def create_raw(symbol_arr, interval_arr, start_time, end_time, step):
        
    for interval in interval_arr:
        for symbol in symbol_arr:
            # Fetch the data using batch requests
            data = []    
            while start_time < end_time:
                limit = min(step, end_time - start_time + 1)  # Adjust the limit for the last batch
                response = client.get_klines(symbol=symbol.upper(), interval=interval, limit=limit, startTime=start_time)

                if len(response) == 0:
                    break  # No more data available, exit the loop
                data.extend(response)
                start_time = response[-1][0] + 1

            # Convert the data to a DataFrame
            columns = [
                "Open_Time", "Open", "High", "Low", "Close", "Volume", "Close_Time",
                "Quote asset volume", "Number of trades", "Taker buy base asset volume",
                "Taker buy quote asset volume", "Ignore"
            ]
            raw_df = pd.DataFrame(data, columns=columns)   

            raw_df = raw_df[['Open_Time', 'Open', 'Close', "High", "Low", 'Volume']]

            dataframes[f'df_{interval}_{symbol}'] = raw_df
            start_time = start_time_d

# %%
loop_start_time = time.time()
create_raw(symbol_arr, interval_arr, start_time_d, end_time, step)
loop_end_time = time.time()
print("Time taken to execute for loop:", loop_end_time - loop_start_time, "seconds")
print(dataframes)
# Out:
# Time taken to execute for loop: 42.48861384391785 seconds
# {'df_1h_ethusdt':            Open_Time           Open          Close           High  \
# 0      1635746400000  4225.00000000  4241.99000000  4259.14000000
# 1      1635750000000  4241.99000000  4302.93000000  4320.00000000
# 2      1635753600000  4302.94000000  4311.11000000  4338.07000000
# 3      1635757200000  4311.11000000  4316.56000000  4344.41000000
# 4      1635760800000  4316.55000000  4328.94000000  4335.00000000
# ...              ...            ...            ...            ...
# 13925  1685880000000  1903.07000000  1904.43000000  1904.81000000
# 13926  1685883600000  1904.43000000  1907.51000000  1914.63000000
# 13927  1685887200000  1907.52000000  1905.50000000  1908.38000000
# 13928  1685890800000  1905.51000000  1901.76000000  1906.31000000
# 13929  1685894400000  1901.76000000  1898.56000000  1902.26000000
#
#                  Low          Volume
# 0      4198.55000000  13908.93710000
# 1      4241.46000000  31363.21900000
# 2      4294.52000000  21038.55420000
# 3      4310.64000000  16175.35920000
# 4      4313.86000000  11207.71110000
# ...              ...             ...
# 13925  1901.41000000   5389.99170000
# 13926  1903.06000000  14262.13160000
# 13927  1900.00000000  13258.26780000
# 13928  1901.53000000   6183.39160000
# 13929  1898.00000000   4627.66800000
#
# [13930 rows x 6 columns], 'df_1h_nearusdt':            Open_Time         Open        Close         High          Low  \
# 0      1635746400000  10.43700000  10.39700000  10.56100000  10.26500000
# 1      1635750000000  10.40400000  10.44200000  10.54400000  10.35700000
# 2      1635753600000  10.44500000  10.40600000  10.52800000  10.38500000
# 3      1635757200000  10.40500000  10.29200000  10.45400000  10.23900000
# 4      1635760800000  10.29200000  10.25200000  10.35000000  10.22000000
# ...              ...          ...          ...          ...          ...
# 13925  1685880000000   1.64000000   1.64400000   1.64400000   1.63600000
# 13926  1685883600000   1.64300000   1.64200000   1.64800000   1.64000000
# 13927  1685887200000   1.64100000   1.63500000   1.64300000   1.62800000
# 13928  1685890800000   1.63500000   1.63500000   1.63800000   1.63100000
# 13929  1685894400000   1.63400000   1.63200000   1.63800000   1.63200000
#
#                 Volume
# 0      358570.90000000
# 1      436951.70000000
# 2      476371.80000000
# 3      438768.10000000
# 4      314673.90000000
# ...                ...
# 13925   86370.90000000
# 13926  119335.70000000
# 13927  126072.00000000
# 13928   70065.20000000
# 13929   23024.00000000
#
# [13930 rows x 6 columns], 'df_1h_ftmusdt':            Open_Time        Open       Close        High         Low  \
# 0      1635746400000  2.81940000  2.81500000  2.87860000  2.79190000
# 1      1635750000000  2.81620000  2.86700000  2.91000000  2.81490000
# 2      1635753600000  2.86640000  2.83380000  2.89540000  2.82900000
# 3      1635757200000  2.83350000  2.85750000  2.87000000  2.83010000
# 4      1635760800000  2.85750000  2.81500000  2.86100000  2.81500000
# ...              ...         ...         ...         ...         ...
# 13925  1685880000000  0.32030000  0.32100000  0.32110000  0.31970000
# 13926  1685883600000  0.32100000  0.32050000  0.32220000  0.32040000
# 13927  1685887200000  0.32050000  0.31980000  0.32070000  0.31830000
# 13928  1685890800000  0.31970000  0.31940000  0.31990000  0.31850000
# 13929  1685894400000  0.31940000  0.31960000  0.32000000  0.31820000
#
#                  Volume
# 0      5023525.00000000
# 1      4723813.00000000
# 2      3347471.00000000
# 3      3021817.00000000
# 4      3293481.00000000
# ...                 ...
# 13925  1083203.00000000
# 13926  2004096.00000000
# 13927  2477334.00000000
# 13928  1152860.00000000
# 13929   662123.00000000
#
# [13930 rows x 6 columns], 'df_1h_sandusdt':            Open_Time        Open       Close        High         Low  \
# 0      1635746400000  1.63890000  1.58540000  1.65910000  1.57100000
# 1      1635750000000  1.58600000  1.68090000  1.68680000  1.58560000
# 2      1635753600000  1.68080000  1.66060000  1.70650000  1.64130000
# 3      1635757200000  1.66060000  1.79530000  1.80130000  1.65950000
# 4      1635760800000  1.79500000  1.98700000  2.01730000  1.77780000
# ...              ...         ...         ...         ...         ...
# 13925  1685880000000  0.57720000  0.58130000  0.58160000  0.57670000
# 13926  1685883600000  0.58140000  0.57960000  0.58190000  0.57860000
# 13927  1685887200000  0.57970000  0.57400000  0.58260000  0.57040000
# 13928  1685890800000  0.57390000  0.57530000  0.57630000  0.57230000
# 13929  1685894400000  0.57520000  0.57200000  0.57560000  0.57200000
#
#                   Volume
# 0       5587421.00000000
# 1       7977745.00000000
# 2       5912663.00000000
# 3      11438578.00000000
# 4      40229855.00000000
# ...                  ...
# 13925   1905570.00000000
# 13926   1200550.00000000
# 13927   3686887.00000000
# 13928    933258.00000000
# 13929    271261.00000000
#
# [13930 rows x 6 columns], 'df_1h_woousdt':            Open_Time        Open       Close        High         Low  \
# 0      1644300000000  0.68680000  0.78360000  0.87900000  0.68680000
# 1      1644303600000  0.78360000  0.80450000  0.83900000  0.76800000
# 2      1644307200000  0.80450000  0.77360000  0.80470000  0.76050000
# 3      1644310800000  0.77320000  0.76390000  0.79300000  0.75080000
# 4      1644314400000  0.76250000  0.75370000  0.76840000  0.75120000
# ...              ...         ...         ...         ...         ...
# 11549  1685880000000  0.24630000  0.24750000  0.24790000  0.24600000
# 11550  1685883600000  0.24750000  0.24810000  0.24900000  0.24750000
# 11551  1685887200000  0.24800000  0.24460000  0.24880000  0.24420000
# 11552  1685890800000  0.24470000  0.24300000  0.24480000  0.24290000
# 11553  1685894400000  0.24310000  0.24270000  0.24340000  0.24230000
#
#                   Volume
# 0      10457748.80000000
# 1       5369876.30000000
# 2       2432862.40000000
# 3       1969755.30000000
# 4        762286.40000000
# ...                  ...
# 11549    289337.10000000
# 11550    658013.30000000
# 11551    791561.10000000
# 11552    547977.30000000
# 11553    103364.90000000
#
# [11554 rows x 6 columns], 'df_1h_dydxusdt':            Open_Time         Open        Close         High          Low  \
# 0      1635746400000  17.41100000  17.30000000  17.72500000  16.90100000
# 1      1635750000000  17.30000000  17.33700000  17.75700000  17.08800000
# 2      1635753600000  17.33900000  17.46700000  17.81600000  17.18600000
# 3      1635757200000  17.46600000  17.45900000  17.56300000  17.02100000
# 4      1635760800000  17.45900000  17.01300000  17.75000000  16.89900000
# ...              ...          ...          ...          ...          ...
# 13925  1685880000000   2.10600000   2.11100000   2.11100000   2.10300000
# 13926  1685883600000   2.11000000   2.12000000   2.12900000   2.10800000
# 13927  1685887200000   2.11900000   2.11300000   2.12400000   2.10600000
# 13928  1685890800000   2.11300000   2.10700000   2.12000000   2.10700000
# 13929  1685894400000   2.10800000   2.10400000   2.10900000   2.10100000
#
#                  Volume
# 0      1233025.27000000
# 1       705716.25000000
# 2       507274.05000000
# 3       308537.73000000
# 4       515571.26000000
# ...                 ...
# 13925    48806.79000000
# 13926   166014.78000000
# 13927   238456.98000000
# 13928    87036.14000000
# 13929    33387.35000000
#
# [13930 rows x 6 columns], 'df_1h_atomusdt':            Open_Time         Open        Close         High          Low  \
# 0      1635746400000  35.57000000  35.58000000  35.73000000  35.24000000
# 1      1635750000000  35.58000000  36.29000000  36.31000000  35.58000000
# 2      1635753600000  36.26000000  36.65000000  36.65000000  36.05000000
# 3      1635757200000  36.64000000  37.28000000  37.39000000  36.58000000
# 4      1635760800000  37.26000000  36.93000000  37.72000000  36.82000000
# ...              ...          ...          ...          ...          ...
# 13925  1685880000000  10.79800000  10.83600000  10.84400000  10.79600000
# 13926  1685883600000  10.83600000  10.81000000  10.83700000  10.80500000
# 13927  1685887200000  10.81000000  10.80300000  10.81100000  10.77300000
# 13928  1685890800000  10.80300000  10.74000000  10.81800000  10.73400000
# 13929  1685894400000  10.74000000  10.74400000  10.75500000  10.73100000
#
#                 Volume
# 0       79622.10000000
# 1      140355.30000000
# 2      117452.15000000
# 3      154840.64000000
# 4      222916.96000000
# ...                ...
# 13925   26816.70000000
# 13926   33895.85000000
# 13927   45561.20000000
# 13928   49342.39000000
# 13929    8940.98000000
#
# [13930 rows x 6 columns], 'df_15m_ethusdt':            Open_Time           Open          Close           High  \
# 0      1635743700000  4233.64000000  4238.15000000  4246.31000000
# 1      1635744600000  4238.16000000  4251.22000000  4251.54000000
# 2      1635745500000  4251.23000000  4225.00000000  4252.58000000
# 3      1635746400000  4225.00000000  4209.00000000  4225.99000000
# 4      1635747300000  4208.99000000  4232.36000000  4234.21000000
# ...              ...            ...            ...            ...
# 55715  1685891700000  1902.68000000  1904.79000000  1904.80000000
# 55716  1685892600000  1904.79000000  1903.76000000  1905.81000000
# 55717  1685893500000  1903.77000000  1901.76000000  1904.50000000
# 55718  1685894400000  1901.76000000  1899.67000000  1902.26000000
# 55719  1685895300000  1899.66000000  1898.56000000  1900.00000000
#
#                  Low         Volume
# 0      4231.60000000  2158.18360000
# 1      4238.14000000  3168.48900000
# 2      4220.00000000  4596.06050000
# 3      4203.16000000  4048.43100000
# 4      4198.55000000  3627.54850000
# ...              ...            ...
# 55715  1902.65000000  1161.22380000
# 55716  1903.50000000  1900.11840000
# 55717  1901.53000000  1788.70120000
# 55718  1898.00000000  3983.64570000
# 55719  1898.42000000   647.20360000
#
# [55720 rows x 6 columns], 'df_15m_nearusdt':            Open_Time         Open        Close         High          Low  \
# 0      1635743700000  10.27800000  10.28900000  10.31900000  10.25100000
# 1      1635744600000  10.28900000  10.38100000  10.42500000  10.28400000
# 2      1635745500000  10.38600000  10.44000000  10.63000000  10.37000000
# 3      1635746400000  10.43700000  10.30000000  10.43700000  10.30000000
# 4      1635747300000  10.30000000  10.37200000  10.38000000  10.26500000
# ...              ...          ...          ...          ...          ...
# 55715  1685891700000   1.63100000   1.63500000   1.63500000   1.63100000
# 55716  1685892600000   1.63400000   1.63600000   1.63600000   1.63200000
# 55717  1685893500000   1.63500000   1.63500000   1.63800000   1.63500000
# 55718  1685894400000   1.63400000   1.63600000   1.63800000   1.63200000
# 55719  1685895300000   1.63500000   1.63200000   1.63500000   1.63200000
#
#                 Volume
# 0       39518.10000000
# 1       86034.60000000
# 2      160889.80000000
# 3       95725.00000000
# 4       52494.70000000
# ...                ...
# 55715    9224.80000000
# 55716   21742.00000000
# 55717   14314.70000000
# 55718   20835.60000000
# 55719    2367.70000000
#
# [55720 rows x 6 columns], 'df_15m_ftmusdt':            Open_Time        Open       Close        High         Low  \
# 0      1635743700000  2.80660000  2.81030000  2.82800000  2.79350000
# 1      1635744600000  2.81030000  2.84060000  2.84170000  2.80930000
# 2      1635745500000  2.84000000  2.81850000  2.84160000  2.79640000
# 3      1635746400000  2.81940000  2.85040000  2.86410000  2.79190000
# 4      1635747300000  2.85020000  2.83760000  2.87860000  2.83540000
# ...              ...         ...         ...         ...         ...
# 55715  1685891700000  0.31870000  0.31910000  0.31940000  0.31850000
# 55716  1685892600000  0.31920000  0.31950000  0.31980000  0.31870000
# 55717  1685893500000  0.31940000  0.31940000  0.31990000  0.31920000
# 55718  1685894400000  0.31940000  0.31960000  0.31960000  0.31820000
# 55719  1685895300000  0.31960000  0.31940000  0.32000000  0.31940000
#
#                  Volume
# 0       475604.00000000
# 1       513778.00000000
# 2       862102.00000000
# 3      2301052.00000000
# 4      1491201.00000000
# ...                 ...
# 55715   312234.00000000
# 55716   242165.00000000
# 55717   219459.00000000
# 55718   396737.00000000
# 55719   266258.00000000
#
# [55720 rows x 6 columns], 'df_15m_sandusdt':            Open_Time        Open       Close        High         Low  \
# 0      1635743700000  1.65260000  1.67300000  1.67950000  1.64840000
# 1      1635744600000  1.67220000  1.65480000  1.67460000  1.65290000
# 2      1635745500000  1.65550000  1.63830000  1.66300000  1.63210000
# 3      1635746400000  1.63890000  1.63220000  1.65910000  1.63060000
# 4      1635747300000  1.63160000  1.61220000  1.63530000  1.60340000
# ...              ...         ...         ...         ...         ...
# 55715  1685891700000  0.57250000  0.57470000  0.57480000  0.57250000
# 55716  1685892600000  0.57470000  0.57530000  0.57580000  0.57350000
# 55717  1685893500000  0.57530000  0.57530000  0.57630000  0.57510000
# 55718  1685894400000  0.57520000  0.57300000  0.57560000  0.57280000
# 55719  1685895300000  0.57310000  0.57190000  0.57360000  0.57170000
#
#                  Volume
# 0      1427381.00000000
# 1      1104225.00000000
# 2      2609611.00000000
# 3      1200937.00000000
# 4      1089090.00000000
# ...                 ...
# 55715   219540.00000000
# 55716   245333.00000000
# 55717   202334.00000000
# 55718   211566.00000000
# 55719    63013.00000000
#
# [55720 rows x 6 columns], 'df_15m_woousdt':            Open_Time        Open       Close        High         Low  \
# 0      1644301800000  0.68680000  0.78650000  0.87900000  0.68680000
# 1      1644302700000  0.78590000  0.78360000  0.79000000  0.76030000
# 2      1644303600000  0.78360000  0.78010000  0.81830000  0.76800000
# 3      1644304500000  0.78010000  0.80910000  0.83900000  0.77900000
# 4      1644305400000  0.81180000  0.78760000  0.83500000  0.78720000
# ...              ...         ...         ...         ...         ...
# 46206  1685891700000  0.24350000  0.24360000  0.24390000  0.24340000
# 46207  1685892600000  0.24380000  0.24320000  0.24440000  0.24290000
# 46208  1685893500000  0.24340000  0.24300000  0.24370000  0.24290000
# 46209  1685894400000  0.24310000  0.24290000  0.24340000  0.24230000
# 46210  1685895300000  0.24300000  0.24260000  0.24330000  0.24260000
#
#                  Volume
# 0      9171094.00000000
# 1      1286654.80000000
# 2      2248083.30000000
# 3      1440428.70000000
# 4      1083504.40000000
# ...                 ...
# 46206   150017.60000000
# 46207   108624.40000000
# 46208    54333.30000000
# 46209    87799.90000000
# 46210    15996.60000000
#
# [46211 rows x 6 columns], 'df_15m_dydxusdt':            Open_Time         Open        Close         High          Low  \
# 0      1635743700000  17.12700000  17.06400000  17.27600000  16.68300000
# 1      1635744600000  17.06700000  17.58700000  18.30000000  17.06700000
# 2      1635745500000  17.58300000  17.41600000  17.86000000  17.13700000
# 3      1635746400000  17.41100000  17.35000000  17.71300000  17.15400000
# 4      1635747300000  17.35000000  17.34200000  17.72500000  17.22100000
# ...              ...          ...          ...          ...          ...
# 55715  1685891700000   2.11000000   2.10800000   2.11300000   2.10800000
# 55716  1685892600000   2.10800000   2.11300000   2.11500000   2.10800000
# 55717  1685893500000   2.11500000   2.10700000   2.11500000   2.10700000
# 55718  1685894400000   2.10800000   2.10800000   2.10900000   2.10100000
# 55719  1685895300000   2.10800000   2.10200000   2.10800000   2.10200000
#
#                  Volume
# 0       524616.48000000
# 1      1219952.45000000
# 2       376679.11000000
# 3       417360.29000000
# 4       319491.68000000
# ...                 ...
# 55715    23548.02000000
# 55716    17165.06000000
# 55717    16578.75000000
# 55718    29311.53000000
# 55719     5481.02000000
#
# [55720 rows x 6 columns], 'df_15m_atomusdt':            Open_Time         Open        Close         High          Low  \
# 0      1635743700000  35.48000000  35.58000000  35.63000000  35.41000000
# 1      1635744600000  35.57000000  35.67000000  35.69000000  35.53000000
# 2      1635745500000  35.65000000  35.57000000  35.67000000  35.52000000
# 3      1635746400000  35.57000000  35.43000000  35.59000000  35.38000000
# 4      1635747300000  35.42000000  35.47000000  35.52000000  35.24000000
# ...              ...          ...          ...          ...          ...
# 55715  1685891700000  10.79800000  10.79600000  10.80400000  10.79500000
# 55716  1685892600000  10.79600000  10.78100000  10.79700000  10.77900000
# 55717  1685893500000  10.78100000  10.74000000  10.78600000  10.73400000
# 55718  1685894400000  10.74000000  10.75000000  10.75500000  10.73100000
# 55719  1685895300000  10.75000000  10.74500000  10.75000000  10.74400000
#
#                Volume
# 0      14575.81000000
# 1      12032.02000000
# 2      12928.91000000
# 3      26337.87000000
# 4      16427.77000000
# ...               ...
# 55715   3047.53000000
# 55716  11334.46000000
# 55717  22727.34000000
# 55718   6324.73000000
# 55719   2618.00000000
#
# [55720 rows x 6 columns]}

# %%
def get_klines(symbol, interval, start_time, end_time):
    global dataframes
    df = dataframes[f'df_{interval}_{symbol}']
    df = df[['Open_Time', 'Open', 'Close', "High", "Low", 'Volume']].astype(float)
    df = df.set_index('Open_Time')

    df.index = pd.to_datetime(df.index, unit='ms') + pd.Timedelta(hours=timezone)
    df = df[~df.index.duplicated(keep='first')]

    return df

# %%
def check_cross(df, kd_dir):
    up = df['slow_k'] > df['slow_d']
    down = df['slow_k'] < df['slow_d']
    if kd_dir == 'Up':
        return up.diff() & up
    if kd_dir == 'Any':
        return up.diff()
    if kd_dir == 'Down':
        return down.diff() & down


def indicators(df, kd_dir):

# ema
    for i in (8, 18, 38):
        df['ema_'+str(i)] = ta.trend.ema_indicator(df.Close, window=i)

# atr
    df['atr'] = ta.volatility.average_true_range(df.High, df.Low, df.Close)
    
# rsi
    rsi_int = 14
    df['rsi'] = ta.momentum.RSIIndicator(df['Close'], window = rsi_int).rsi()

# kd

    df['slow_k']= ta.momentum.stoch(df['High'], df['Low'], df['Close'], 17, 5)
    df['slow_d'] = ta.momentum.stoch_signal(df['High'], df['Low'], df['Close'], 17, 5)
    
# kd cross
    df['kd_cross'] = check_cross(df, kd_dir)

# %%
def conditions(df):

    # c1
    df['c1'] = df['kd_cross']
    # c2
    df['c2'] = df['Close'] >= df['ema_8']
    # c3
    df['c3'] = df['ema_8'] >= df['ema_18']
    # c4
    df['c4'] = df['ema_18'] >= df['ema_38']
    df['c5'] = df['Low'] <= df['ema_38']
    
    # signal
    df['signal'] = df['c1'] & df['c2'] & df['c3'] & df['c4'] & df['c5']
    
    # open_entry
    df['open_entry'] = df['signal'].shift()

# %%
def entries(df, sl_atr, tp_atr, sl_det):

    in_position = False
    stop_loss = np.nan
    take_profit = np.nan
    close_val = df['Close']
    atr_val = df['atr']
    
    df['position'] = ''  # Create an empty column for position

    for index, row in df.iterrows():

        if index == 0:
            continue

        elif row['open_entry']:

            df.at[index, 'entry_p'] = close_val.shift(1).at[index]
            df.at[index, 'stop_loss'] = close_val.shift(1).at[index] - sl_atr * atr_val.shift(1).at[index]
            df.at[index, 'take_profit'] = close_val.shift(1).at[index] + tp_atr * atr_val.shift(1).at[index]
            df.at[index, 'position'] = 'Buy'
            in_position = True
            stop_loss = df.at[index, 'stop_loss']
            take_profit = df.at[index, 'take_profit']


        # 吃筍
        #-----------------------------重要-----------------------------
        # 若用 if 寫，則有可能入場馬上吃筍，若用 elif 則一個 iteration 只會執行一次
        elif in_position and row['Close'] <= stop_loss:
            df.at[index, 'position'] = 'Stop'
            in_position = False
            stop_loss = np.nan
            take_profit = np.nan

        # set take profit
        elif in_position and row['High'] >= take_profit:
            df.at[index, 'position'] = 'Sell'
            in_position = False
            stop_loss = np.nan
            take_profit = np.nan
    

    # 過濾有訊號或事件發生的Ｋ線
    df = df[(df['open_entry']) | (df['position'] != '')]

# %%
# 部位回測
def backtest(df):

    df = df.reset_index(drop = True)
    df = df[(df['position'] == 'Buy') |
                  (df['position'] == 'Sell') |
                  (df['position'] == 'Stop')]

    # 一次進場多少單位
    pos_size = 200

    col = ['Open_Time', 'Open', 'Close', 'High', 'Low', 'atr', 'position','entry_p', 'stop_loss', 'take_profit']
    pos = df[col]
    pos = pos.reset_index(drop = True)


    for index, row in pos.iterrows():

        current_pos = 0

        # 進場
        if pos.at[index, 'position'] == 'Buy':
            pos.at[index, 'size'] = pos_size / pos.at[index, 'entry_p']
            pos.exit_p = np.nan

        # 出場
        if pos.at[index, 'position'] == 'Sell' or pos.at[index, 'position'] == 'Stop':

            # 停利：達成條件時收盤價
            if pos.at[index, 'position'] == 'Sell':
                for i in range(index -1, -1, -1):
                    if pos.at[i, 'position'] == 'Buy':
                        pos.at[index, 'exit_p'] = pos.at[i, 'take_profit']
                    break

            # 停損：打到進場停損點（往回跌代，直到最近的'Buy'及其'stop_loss'）
            if pos.at[index, 'position'] == 'Stop':
                pos.at[index, 'exit_p'] = pos.at[index, 'Close']
#                 for i in range(index -1, -1, -1):
#                     if pos.at[i, 'position'] == 'Buy':
#                         pos.at[index, 'exit_p'] = pos.at[i, 'stop_loss']
#                     break

            # 計算每次出場部位大小（每次出場皆清倉）
            for i in range(index -1, -1, -1):
                if pos.at[i, 'position'] == 'Buy':
                    current_pos += pos.at[i, 'size']
                    if i == 0:
                        pos.at[index, 'size'] = -current_pos
                    else:
                        continue
                else:
                    pos.at[index, 'size'] = -current_pos
                    current_pos = 0
                    break


    # 計算部位價值
    for index, row in pos.iterrows():
        if pos.at[index, 'position'] == 'Buy':
            pos.at[index, 'amt'] = round(pos.at[index, 'size'] * pos.at[index, 'entry_p'], 4)
        elif pos.at[index, 'position'] == 'Sell' or pos.at[index, 'position'] == 'Stop':
            pos.at[index, 'amt'] = round(pos.at[index, 'size'] * pos.at[index, 'exit_p'], 4)


    # 若最後一筆為 Buy，移除該單，迭代驗證
    for index, row in pos.iloc[::-1].iterrows():
        if row['position'] == 'Buy':
            pos = pos.drop(index)
        else:
            break


    # 手續費、滑點、價差
    fee = 0.05 / 100
    amt_abs_sum = pos.amt.abs().sum()
    ttl_fee = amt_abs_sum * fee

    # 損益
    leverage = 10
    ttl_profit = -pos.amt.sum() - ttl_fee

    
    # 計算獲利/虧損次數
    agg_amts = []

    for i in range(len(pos) - 1, -1, -1):

        if pos.loc[i, 'position'] in ['Stop', 'Sell']:

            # look out for the + sign
            total_amt = pos.loc[i, 'amt'] + np.absolute(pos.loc[i, 'amt']) * fee

            # iterate backwards from the current row until reaching another 'Stop' or 'Sell'
            # watch out for the + in total_amt += trading_fee
            j = i - 1
            while j >= 0 and pos.loc[j, 'position'] not in ['Stop', 'Sell']:
                total_amt += pos.loc[j, 'amt']
                trading_fee = np.absolute(pos.loc[j, 'amt']) * fee
                total_amt += trading_fee
                j -= 1

            # add the aggregated amount to the list
            agg_amts.append(total_amt)

    agg_amts.reverse()

    
    # 計算進場最大部位，最大損益
    consec_entry = 0
    position_amt_sum = 0
    max_consec_entry = 0
    max_position = 0
    max_profit = 0
    max_loss = 0

    for index, row in pos.iterrows():

        if row['position'] == 'Buy':

            consec_entry += 1
            position_amt_sum += row['amt']

        elif row['position'] in ['Sell', 'Stop']:

            if consec_entry > max_consec_entry:
                max_consec_entry = consec_entry
                max_position = position_amt_sum

            position_amt_sum += row['amt']

            if -position_amt_sum > max_profit:
                max_profit = -position_amt_sum

            if -position_amt_sum < max_loss:
                max_loss = -position_amt_sum

            consec_entry = 0
            position_amt_sum = 0

        else:
            pass


    # 最大部位
    profit_per = "{:.2f}%".format(ttl_profit / (max_position/leverage) * 100)


    # 勝率
    wins = 0
    loses = 0

    for trade in agg_amts:
        if trade < 0:
            wins += 1
        elif trade > 0:
            loses += 1

    win_rate = "{:.2f}%".format(wins / (wins + loses) * 100)
    
    cumulative_values = []
    cumulative_sum = 0

    for value in agg_amts:
        cumulative_sum -= value
        cumulative_values.append(cumulative_sum)

    max_drawdown = min(cumulative_values)

    # 結果
    result = {'Profit': [round(ttl_profit, 2)],
              'Fee': [round(ttl_fee, 2)],
              'Max_Profit': [round(max_profit, 2)],
              'Max_Loss': [round(max_loss, 2)],
              'Max_Entry': [max_consec_entry],
              'Max_Position': [round(max_position, 2)],
              'Profit_%': [profit_per],
              'Win_Rate': [win_rate],
              'PF_Ratio': [round(ttl_profit/ttl_fee, 2)],
              'Max_Drawdown': [round(max_drawdown/ttl_profit, 2)]}


    result_df = pd.DataFrame(result)

    return result_df, ttl_profit, win_rate, ttl_fee

# %%
# iterate using start_time, under same time interval, test different variables
def run_backtest():

    results_df = pd.DataFrame()
    
    symbol_list = []
    interval_list = []
    kd_dir_list = []
    sl_atr_list = []
    tp_atr_list = []
    sl_det_list = []

    i = 0

    loop_start_time = time.time()
    
    parameters = [(symbol, interval, kd_dir, sl_atr, tp_atr, sl_det) 
                  for symbol in symbol_arr
                  for interval in interval_arr
                  for kd_dir in kd_dir_arr
                  for sl_atr in sl_atr_arr
                  for tp_atr in tp_atr_arr
                  for sl_det in sl_det_arr]
    
    for symbol, interval, kd_dir, sl_atr, tp_atr, sl_det in parameters:

        df = get_klines(symbol, interval, start_time_d, end_time)
        df = df.reset_index()

        indicators(df, kd_dir)
        conditions(df)
        entries(df, sl_atr, tp_atr, sl_det)
        
        backtest_df, ttl_profit, win_rate, fee = backtest(df)

        results_df = pd.concat([results_df, backtest_df], ignore_index = True)

        symbol_list.append(symbol)
        interval_list.append(interval)
        kd_dir_list.append(kd_dir)
        sl_atr_list.append(sl_atr)
        tp_atr_list.append(tp_atr)
        sl_det_list.append(sl_det)

        i += 1

        print(f" {i} - {symbol}, {interval}, sl: {sl_atr}, tp: {tp_atr}, {sl_det}, {round(ttl_profit, 2)}, {round(fee, 2)}, {round(ttl_profit/fee, 2)}, {win_rate} ")

    loop_end_time = time.time()

    print("Time taken to execute for loop:", loop_end_time - loop_start_time, "seconds")

    results_df['symbol'] = symbol_list
    results_df['interval'] = interval_list
    results_df['kd_dir'] = kd_dir_list
    results_df['sl_atr'] = sl_atr_list
    results_df['tp_atr'] = tp_atr_list
    results_df['sl_det'] = sl_det_list

    results_df = results_df[['symbol', 'interval', 'kd_dir',
                             'sl_atr', 'tp_atr', 'sl_det',
                             'Profit', 'Fee', 'Max_Profit', 'Max_Loss',
                             'Max_Entry', 'Max_Position', 'Profit_%', 'Win_Rate', 'PF_Ratio', 'Max_Drawdown'
                            ]]
    
    return results_df

# %%
results_df = run_backtest()
results_df = results_df.sort_values('Profit', ascending = False)
# print(results_df)
# Out:
#  1 - ethusdt, 1h, sl: 1, tp: 3, Close, 143.99, 225.22, 0.64, 35.90%
#  2 - ethusdt, 1h, sl: 1, tp: 5, Close, 51.43, 225.17, 0.23, 22.37%
#  3 - ethusdt, 1h, sl: 1, tp: 9, Close, -433.86, 224.93, -1.93, 15.07%
#  4 - ethusdt, 1h, sl: 1, tp: 12, Close, -575.08, 224.86, -2.56, 12.68%
#  5 - ethusdt, 1h, sl: 3, tp: 3, Close, -1143.53, 222.67, -5.14, 50.00%
#  6 - ethusdt, 1h, sl: 3, tp: 5, Close, -1120.11, 222.68, -5.03, 36.51%
#  7 - ethusdt, 1h, sl: 3, tp: 9, Close, -1625.56, 222.43, -7.31, 22.81%
#  8 - ethusdt, 1h, sl: 3, tp: 12, Close, -1478.63, 222.5, -6.65, 16.36%
#  9 - ethusdt, 1h, sl: 5, tp: 3, Close, -1646.15, 222.42, -7.4, 59.68%
#  10 - ethusdt, 1h, sl: 5, tp: 5, Close, -2442.93, 222.02, -11.0, 45.61%
#  11 - ethusdt, 1h, sl: 5, tp: 9, Close, -3601.15, 221.44, -16.26, 30.00%
#  12 - ethusdt, 1h, sl: 5, tp: 12, Close, -3394.64, 221.55, -15.32, 22.92%
#  13 - ethusdt, 1h, sl: 7, tp: 3, Close, -808.45, 220.93, -3.66, 69.09%
#  14 - ethusdt, 1h, sl: 7, tp: 5, Close, -1346.5, 220.66, -6.1, 56.25%
#  15 - ethusdt, 1h, sl: 7, tp: 9, Close, -1180.94, 220.75, -5.35, 42.50%
#  16 - ethusdt, 1h, sl: 7, tp: 12, Close, -1465.5, 220.61, -6.64, 31.58%
#  17 - ethusdt, 1h, sl: 1, tp: 3, Close, 81.19, 199.74, 0.41, 34.67%
#  18 - ethusdt, 1h, sl: 1, tp: 5, Close, -122.63, 199.64, -0.61, 20.55%
#  19 - ethusdt, 1h, sl: 1, tp: 9, Close, -476.3, 199.46, -2.39, 12.68%
#  20 - ethusdt, 1h, sl: 1, tp: 12, Close, -483.38, 199.46, -2.42, 11.59%
#  21 - ethusdt, 1h, sl: 3, tp: 3, Close, -847.93, 197.37, -4.3, 50.79%
#  22 - ethusdt, 1h, sl: 3, tp: 5, Close, -853.29, 197.37, -4.32, 36.67%
#  23 - ethusdt, 1h, sl: 3, tp: 9, Close, -1225.92, 197.18, -6.22, 22.22%
#  24 - ethusdt, 1h, sl: 3, tp: 12, Close, -922.4, 197.34, -4.67, 17.31%
#  25 - ethusdt, 1h, sl: 5, tp: 3, Close, -1267.16, 197.16, -6.43, 61.67%
#  26 - ethusdt, 1h, sl: 5, tp: 5, Close, -1967.94, 196.81, -10.0, 47.27%
#  27 - ethusdt, 1h, sl: 5, tp: 9, Close, -2882.8, 196.36, -14.68, 31.25%
#  28 - ethusdt, 1h, sl: 5, tp: 12, Close, -2402.73, 196.6, -12.22, 26.09%
#  29 - ethusdt, 1h, sl: 7, tp: 3, Close, -231.05, 195.78, -1.18, 71.70%
#  30 - ethusdt, 1h, sl: 7, tp: 5, Close, -503.33, 195.64, -2.57, 58.70%
#  31 - ethusdt, 1h, sl: 7, tp: 9, Close, -405.97, 195.69, -2.07, 44.74%
#  32 - ethusdt, 1h, sl: 7, tp: 12, Close, -405.35, 195.69, -2.07, 36.11%
#  33 - ethusdt, 15m, sl: 1, tp: 3, Close, -610.81, 1119.92, -0.55, 35.53%
#  34 - ethusdt, 15m, sl: 1, tp: 5, Close, 85.68, 1120.27, 0.08, 24.87%
#  35 - ethusdt, 15m, sl: 1, tp: 9, Close, 320.67, 1120.39, 0.29, 17.27%
#  36 - ethusdt, 15m, sl: 1, tp: 12, Close, -183.18, 1118.24, -0.16, 14.49%
#  37 - ethusdt, 15m, sl: 3, tp: 3, Close, -259.68, 1120.1, -0.23, 55.80%
#  38 - ethusdt, 15m, sl: 3, tp: 5, Close, -716.44, 1119.87, -0.64, 41.44%
#  39 - ethusdt, 15m, sl: 3, tp: 9, Close, -226.26, 1120.11, -0.2, 26.24%
#  40 - ethusdt, 15m, sl: 3, tp: 12, Close, -823.39, 1117.92, -0.74, 19.67%
#  41 - ethusdt, 15m, sl: 5, tp: 3, Close, -214.88, 1120.12, -0.19, 67.91%
#  42 - ethusdt, 15m, sl: 5, tp: 5, Close, -1851.61, 1119.3, -1.65, 53.44%
#  43 - ethusdt, 15m, sl: 5, tp: 9, Close, -2153.07, 1119.15, -1.92, 34.39%
#  44 - ethusdt, 15m, sl: 5, tp: 12, Close, -5023.12, 1110.21, -4.52, 25.37%
#  45 - ethusdt, 15m, sl: 7, tp: 3, Close, -823.54, 1119.81, -0.74, 75.27%
#  46 - ethusdt, 15m, sl: 7, tp: 5, Close, -3545.04, 1118.45, -3.17, 61.89%
#  47 - ethusdt, 15m, sl: 7, tp: 9, Close, -4337.82, 1118.06, -3.88, 41.75%
#  48 - ethusdt, 15m, sl: 7, tp: 12, Close, -7622.86, 1108.91, -6.87, 31.36%
#  49 - ethusdt, 15m, sl: 1, tp: 3, Close, -736.57, 1046.31, -0.7, 35.45%
#  50 - ethusdt, 15m, sl: 1, tp: 5, Close, -35.87, 1046.66, -0.03, 25.07%
#  51 - ethusdt, 15m, sl: 1, tp: 9, Close, -19.33, 1046.66, -0.02, 17.34%
#  52 - ethusdt, 15m, sl: 1, tp: 12, Close, -70.73, 1044.74, -0.07, 14.07%
#  53 - ethusdt, 15m, sl: 3, tp: 3, Close, -617.15, 1046.37, -0.59, 54.98%
#  54 - ethusdt, 15m, sl: 3, tp: 5, Close, -871.12, 1046.24, -0.83, 41.40%
#  55 - ethusdt, 15m, sl: 3, tp: 9, Close, -551.58, 1046.4, -0.53, 26.07%
#  56 - ethusdt, 15m, sl: 3, tp: 12, Close, -555.81, 1044.5, -0.53, 18.75%
#  57 - ethusdt, 15m, sl: 5, tp: 3, Close, -523.62, 1046.41, -0.5, 67.36%
#  58 - ethusdt, 15m, sl: 5, tp: 5, Close, -1810.13, 1045.77, -1.73, 53.73%
#  59 - ethusdt, 15m, sl: 5, tp: 9, Close, -2219.47, 1045.56, -2.12, 34.42%
#  60 - ethusdt, 15m, sl: 5, tp: 12, Close, -4363.11, 1036.99, -4.21, 25.89%
#  61 - ethusdt, 15m, sl: 7, tp: 3, Close, -1020.27, 1046.16, -0.98, 74.91%
#  62 - ethusdt, 15m, sl: 7, tp: 5, Close, -3479.95, 1044.93, -3.33, 62.18%
#  63 - ethusdt, 15m, sl: 7, tp: 9, Close, -4378.21, 1044.48, -4.19, 41.80%
#  64 - ethusdt, 15m, sl: 7, tp: 12, Close, -6739.38, 1035.8, -6.51, 31.33%
#  65 - nearusdt, 1h, sl: 1, tp: 3, Close, -6.15, 0.48, -12.93, 27.87%
#  66 - nearusdt, 1h, sl: 1, tp: 5, Close, -5.98, 0.48, -12.59, 19.67%
#  67 - nearusdt, 1h, sl: 1, tp: 9, Close, -2.6, 0.48, -5.45, 15.79%
#  68 - nearusdt, 1h, sl: 1, tp: 12, Close, 0.32, 0.48, 0.66, 15.79%
#  69 - nearusdt, 1h, sl: 3, tp: 3, Close, -12.31, 0.47, -26.06, 41.07%
#  70 - nearusdt, 1h, sl: 3, tp: 5, Close, -14.46, 0.47, -30.7, 27.27%
#  71 - nearusdt, 1h, sl: 3, tp: 9, Close, -7.67, 0.47, -16.16, 18.00%
#  72 - nearusdt, 1h, sl: 3, tp: 12, Close, -2.84, 0.48, -5.95, 18.00%
#  73 - nearusdt, 1h, sl: 5, tp: 3, Close, -16.13, 0.47, -34.31, 54.90%
#  74 - nearusdt, 1h, sl: 5, tp: 5, Close, -20.13, 0.47, -42.98, 36.73%
#  75 - nearusdt, 1h, sl: 5, tp: 9, Close, -10.84, 0.47, -22.92, 27.27%
#  76 - nearusdt, 1h, sl: 5, tp: 12, Close, -11.68, 0.47, -24.72, 25.00%
#  77 - nearusdt, 1h, sl: 7, tp: 3, Close, -16.93, 0.47, -36.04, 60.42%
#  78 - nearusdt, 1h, sl: 7, tp: 5, Close, -19.75, 0.47, -42.17, 45.65%
#  79 - nearusdt, 1h, sl: 7, tp: 9, Close, -13.94, 0.47, -29.58, 39.02%
#  80 - nearusdt, 1h, sl: 7, tp: 12, Close, -15.06, 0.47, -32.0, 32.50%
#  81 - nearusdt, 1h, sl: 1, tp: 3, Close, -5.33, 0.43, -12.42, 28.81%
#  82 - nearusdt, 1h, sl: 1, tp: 5, Close, -5.16, 0.43, -12.04, 20.34%
#  83 - nearusdt, 1h, sl: 1, tp: 9, Close, -1.78, 0.43, -4.14, 16.36%
#  84 - nearusdt, 1h, sl: 1, tp: 12, Close, 1.14, 0.43, 2.63, 16.36%
#  85 - nearusdt, 1h, sl: 3, tp: 3, Close, -10.5, 0.43, -24.64, 41.82%
#  86 - nearusdt, 1h, sl: 3, tp: 5, Close, -12.45, 0.43, -29.27, 29.09%
#  87 - nearusdt, 1h, sl: 3, tp: 9, Close, -5.78, 0.43, -13.48, 18.37%
#  88 - nearusdt, 1h, sl: 3, tp: 12, Close, -0.95, 0.43, -2.19, 18.37%
#  89 - nearusdt, 1h, sl: 5, tp: 3, Close, -14.97, 0.42, -35.29, 52.00%
#  90 - nearusdt, 1h, sl: 5, tp: 5, Close, -19.26, 0.42, -45.64, 36.73%
#  91 - nearusdt, 1h, sl: 5, tp: 9, Close, -11.43, 0.43, -26.84, 25.58%
#  92 - nearusdt, 1h, sl: 5, tp: 12, Close, -4.65, 0.43, -10.84, 25.58%
#  93 - nearusdt, 1h, sl: 7, tp: 3, Close, -17.51, 0.42, -41.42, 59.57%
#  94 - nearusdt, 1h, sl: 7, tp: 5, Close, -21.97, 0.42, -52.25, 47.83%
#  95 - nearusdt, 1h, sl: 7, tp: 9, Close, -17.75, 0.42, -41.99, 37.50%
#  96 - nearusdt, 1h, sl: 7, tp: 12, Close, -11.87, 0.43, -27.88, 33.33%
#  97 - nearusdt, 15m, sl: 1, tp: 3, Close, -6.11, 2.58, -2.37, 28.83%
#  98 - nearusdt, 15m, sl: 1, tp: 5, Close, -10.34, 2.58, -4.01, 18.83%
#  99 - nearusdt, 15m, sl: 1, tp: 9, Close, -13.33, 2.58, -5.17, 12.01%
#  100 - nearusdt, 15m, sl: 1, tp: 12, Close, -10.36, 2.58, -4.02, 11.48%
#  101 - nearusdt, 15m, sl: 3, tp: 3, Close, -8.2, 2.58, -3.18, 52.00%
#  102 - nearusdt, 15m, sl: 3, tp: 5, Close, -21.39, 2.57, -8.31, 37.55%
#  103 - nearusdt, 15m, sl: 3, tp: 9, Close, -26.4, 2.56, -10.29, 20.72%
#  104 - nearusdt, 15m, sl: 3, tp: 12, Close, -18.58, 2.57, -7.23, 17.59%
#  105 - nearusdt, 15m, sl: 5, tp: 3, Close, -13.83, 2.58, -5.37, 61.63%
#  106 - nearusdt, 15m, sl: 5, tp: 5, Close, -38.0, 2.56, -14.82, 47.32%
#  107 - nearusdt, 15m, sl: 5, tp: 9, Close, -45.5, 2.55, -17.83, 25.41%
#  108 - nearusdt, 15m, sl: 5, tp: 12, Close, -34.23, 2.56, -13.38, 21.35%
#  109 - nearusdt, 15m, sl: 7, tp: 3, Close, -16.11, 2.57, -6.26, 66.53%
#  110 - nearusdt, 15m, sl: 7, tp: 5, Close, -34.66, 2.57, -13.51, 53.66%
#  111 - nearusdt, 15m, sl: 7, tp: 9, Close, -36.01, 2.56, -14.08, 31.25%
#  112 - nearusdt, 15m, sl: 7, tp: 12, Close, -15.69, 2.57, -6.11, 25.66%
#  113 - nearusdt, 15m, sl: 1, tp: 3, Close, -5.06, 2.46, -2.06, 29.50%
#  114 - nearusdt, 15m, sl: 1, tp: 5, Close, -9.42, 2.46, -3.83, 19.17%
#  115 - nearusdt, 15m, sl: 1, tp: 9, Close, -11.99, 2.45, -4.88, 12.42%
#  116 - nearusdt, 15m, sl: 1, tp: 12, Close, -9.01, 2.46, -3.67, 11.86%
#  117 - nearusdt, 15m, sl: 3, tp: 3, Close, -5.5, 2.46, -2.24, 52.26%
#  118 - nearusdt, 15m, sl: 3, tp: 5, Close, -18.79, 2.45, -7.67, 37.55%
#  119 - nearusdt, 15m, sl: 3, tp: 9, Close, -23.46, 2.44, -9.6, 20.74%
#  120 - nearusdt, 15m, sl: 3, tp: 12, Close, -16.11, 2.45, -6.58, 17.54%
#  121 - nearusdt, 15m, sl: 5, tp: 3, Close, -8.56, 2.46, -3.48, 61.75%
#  122 - nearusdt, 15m, sl: 5, tp: 5, Close, -32.8, 2.44, -13.42, 47.25%
#  123 - nearusdt, 15m, sl: 5, tp: 9, Close, -39.05, 2.43, -16.05, 25.82%
#  124 - nearusdt, 15m, sl: 5, tp: 12, Close, -28.22, 2.44, -11.57, 21.71%
#  125 - nearusdt, 15m, sl: 7, tp: 3, Close, -10.0, 2.46, -4.07, 66.67%
#  126 - nearusdt, 15m, sl: 7, tp: 5, Close, -28.79, 2.45, -11.77, 53.73%
#  127 - nearusdt, 15m, sl: 7, tp: 9, Close, -28.38, 2.44, -11.64, 32.08%
#  128 - nearusdt, 15m, sl: 7, tp: 12, Close, -8.67, 2.45, -3.54, 26.49%
#  129 - ftmusdt, 1h, sl: 1, tp: 3, Close, -0.29, 0.06, -5.11, 25.00%
#  130 - ftmusdt, 1h, sl: 1, tp: 5, Close, -0.02, 0.06, -0.4, 17.81%
#  131 - ftmusdt, 1h, sl: 1, tp: 9, Close, 0.45, 0.06, 8.02, 12.86%
#  132 - ftmusdt, 1h, sl: 1, tp: 12, Close, 0.43, 0.06, 7.67, 11.43%
#  133 - ftmusdt, 1h, sl: 3, tp: 3, Close, -0.03, 0.06, -0.51, 50.00%
#  134 - ftmusdt, 1h, sl: 3, tp: 5, Close, -0.17, 0.06, -2.96, 38.46%
#  135 - ftmusdt, 1h, sl: 3, tp: 9, Close, 0.0, 0.06, 0.05, 23.40%
#  136 - ftmusdt, 1h, sl: 3, tp: 12, Close, 0.15, 0.06, 2.57, 21.28%
#  137 - ftmusdt, 1h, sl: 5, tp: 3, Close, 0.15, 0.06, 2.66, 65.38%
#  138 - ftmusdt, 1h, sl: 5, tp: 5, Close, -0.46, 0.06, -8.2, 53.33%
#  139 - ftmusdt, 1h, sl: 5, tp: 9, Close, -0.07, 0.06, -1.25, 37.50%
#  140 - ftmusdt, 1h, sl: 5, tp: 12, Close, -0.37, 0.06, -6.6, 35.00%
#  141 - ftmusdt, 1h, sl: 7, tp: 3, Close, -0.23, 0.06, -4.05, 68.63%
#  142 - ftmusdt, 1h, sl: 7, tp: 5, Close, -1.31, 0.06, -23.42, 54.55%
#  143 - ftmusdt, 1h, sl: 7, tp: 9, Close, -1.14, 0.06, -20.38, 39.47%
#  144 - ftmusdt, 1h, sl: 7, tp: 12, Close, -1.55, 0.06, -27.85, 36.84%
#  145 - ftmusdt, 1h, sl: 1, tp: 3, Close, -0.2, 0.05, -3.73, 26.03%
#  146 - ftmusdt, 1h, sl: 1, tp: 5, Close, 0.07, 0.05, 1.32, 18.57%
#  147 - ftmusdt, 1h, sl: 1, tp: 9, Close, 0.55, 0.05, 10.34, 13.43%
#  148 - ftmusdt, 1h, sl: 1, tp: 12, Close, 0.53, 0.05, 9.96, 11.94%
#  149 - ftmusdt, 1h, sl: 3, tp: 3, Close, 0.03, 0.05, 0.59, 52.73%
#  150 - ftmusdt, 1h, sl: 3, tp: 5, Close, 0.01, 0.05, 0.11, 40.82%
#  151 - ftmusdt, 1h, sl: 3, tp: 9, Close, 0.17, 0.05, 3.19, 25.00%
#  152 - ftmusdt, 1h, sl: 3, tp: 12, Close, 0.31, 0.05, 5.79, 22.73%
#  153 - ftmusdt, 1h, sl: 5, tp: 3, Close, 0.28, 0.05, 5.37, 68.00%
#  154 - ftmusdt, 1h, sl: 5, tp: 5, Close, -0.19, 0.05, -3.59, 55.81%
#  155 - ftmusdt, 1h, sl: 5, tp: 9, Close, 0.2, 0.05, 3.7, 39.47%
#  156 - ftmusdt, 1h, sl: 5, tp: 12, Close, -0.11, 0.05, -2.12, 36.84%
#  157 - ftmusdt, 1h, sl: 7, tp: 3, Close, 0.0, 0.05, 0.06, 71.43%
#  158 - ftmusdt, 1h, sl: 7, tp: 5, Close, -0.89, 0.05, -17.07, 57.14%
#  159 - ftmusdt, 1h, sl: 7, tp: 9, Close, -0.73, 0.05, -13.97, 41.67%
#  160 - ftmusdt, 1h, sl: 7, tp: 12, Close, -1.15, 0.05, -22.05, 38.89%
#  161 - ftmusdt, 15m, sl: 1, tp: 3, Close, -1.21, 0.34, -3.53, 26.55%
#  162 - ftmusdt, 15m, sl: 1, tp: 5, Close, -1.67, 0.34, -4.87, 16.28%
#  163 - ftmusdt, 15m, sl: 1, tp: 9, Close, -1.91, 0.34, -5.59, 9.70%
#  164 - ftmusdt, 15m, sl: 1, tp: 12, Close, -1.6, 0.34, -4.68, 9.57%
#  165 - ftmusdt, 15m, sl: 3, tp: 3, Close, -2.23, 0.34, -6.52, 45.36%
#  166 - ftmusdt, 15m, sl: 3, tp: 5, Close, -2.58, 0.34, -7.54, 29.74%
#  167 - ftmusdt, 15m, sl: 3, tp: 9, Close, -3.23, 0.34, -9.47, 17.96%
#  168 - ftmusdt, 15m, sl: 3, tp: 12, Close, -3.52, 0.34, -10.31, 14.83%
#  169 - ftmusdt, 15m, sl: 5, tp: 3, Close, -0.8, 0.34, -2.35, 62.60%
#  170 - ftmusdt, 15m, sl: 5, tp: 5, Close, -0.29, 0.34, -0.86, 45.50%
#  171 - ftmusdt, 15m, sl: 5, tp: 9, Close, -2.25, 0.34, -6.61, 27.32%
#  172 - ftmusdt, 15m, sl: 5, tp: 12, Close, -1.86, 0.34, -5.45, 21.31%
#  173 - ftmusdt, 15m, sl: 7, tp: 3, Close, -1.4, 0.34, -4.09, 67.08%
#  174 - ftmusdt, 15m, sl: 7, tp: 5, Close, -0.57, 0.34, -1.66, 53.17%
#  175 - ftmusdt, 15m, sl: 7, tp: 9, Close, -0.19, 0.34, -0.56, 33.53%
#  176 - ftmusdt, 15m, sl: 7, tp: 12, Close, 0.4, 0.34, 1.17, 26.42%
#  177 - ftmusdt, 15m, sl: 1, tp: 3, Close, -0.91, 0.33, -2.8, 26.59%
#  178 - ftmusdt, 15m, sl: 1, tp: 5, Close, -1.34, 0.33, -4.12, 16.96%
#  179 - ftmusdt, 15m, sl: 1, tp: 9, Close, -1.56, 0.33, -4.78, 9.94%
#  180 - ftmusdt, 15m, sl: 1, tp: 12, Close, -1.25, 0.33, -3.82, 9.81%
#  181 - ftmusdt, 15m, sl: 3, tp: 3, Close, -2.08, 0.33, -6.38, 45.20%
#  182 - ftmusdt, 15m, sl: 3, tp: 5, Close, -2.42, 0.33, -7.43, 30.53%
#  183 - ftmusdt, 15m, sl: 3, tp: 9, Close, -3.07, 0.33, -9.43, 18.07%
#  184 - ftmusdt, 15m, sl: 3, tp: 12, Close, -2.82, 0.33, -8.66, 15.28%
#  185 - ftmusdt, 15m, sl: 5, tp: 3, Close, -2.0, 0.33, -6.13, 62.20%
#  186 - ftmusdt, 15m, sl: 5, tp: 5, Close, -1.73, 0.33, -5.33, 46.54%
#  187 - ftmusdt, 15m, sl: 5, tp: 9, Close, -4.49, 0.32, -13.88, 26.98%
#  188 - ftmusdt, 15m, sl: 5, tp: 12, Close, -4.11, 0.32, -12.7, 21.35%
#  189 - ftmusdt, 15m, sl: 7, tp: 3, Close, -1.49, 0.33, -4.56, 67.37%
#  190 - ftmusdt, 15m, sl: 7, tp: 5, Close, -0.57, 0.33, -1.76, 53.96%
#  191 - ftmusdt, 15m, sl: 7, tp: 9, Close, -0.3, 0.33, -0.91, 33.53%
#  192 - ftmusdt, 15m, sl: 7, tp: 12, Close, 0.7, 0.33, 2.15, 26.92%
#  193 - sandusdt, 1h, sl: 1, tp: 3, Close, 0.56, 0.11, 5.24, 39.66%
#  194 - sandusdt, 1h, sl: 1, tp: 5, Close, 0.83, 0.11, 7.82, 30.91%
#  195 - sandusdt, 1h, sl: 1, tp: 9, Close, 0.52, 0.11, 4.92, 20.75%
#  196 - sandusdt, 1h, sl: 1, tp: 12, Close, 1.18, 0.11, 11.04, 18.87%
#  197 - sandusdt, 1h, sl: 3, tp: 3, Close, -0.04, 0.11, -0.39, 53.06%
#  198 - sandusdt, 1h, sl: 3, tp: 5, Close, 0.85, 0.11, 7.98, 47.83%
#  199 - sandusdt, 1h, sl: 3, tp: 9, Close, -0.21, 0.11, -2.01, 29.27%
#  200 - sandusdt, 1h, sl: 3, tp: 12, Close, -0.12, 0.11, -1.13, 25.00%
#  201 - sandusdt, 1h, sl: 5, tp: 3, Close, -0.54, 0.11, -5.07, 60.87%
#  202 - sandusdt, 1h, sl: 5, tp: 5, Close, 0.08, 0.11, 0.73, 53.49%
#  203 - sandusdt, 1h, sl: 5, tp: 9, Close, -2.32, 0.11, -22.05, 32.43%
#  204 - sandusdt, 1h, sl: 5, tp: 12, Close, -2.41, 0.1, -22.99, 27.78%
#  205 - sandusdt, 1h, sl: 7, tp: 3, Close, -1.36, 0.11, -12.85, 64.44%
#  206 - sandusdt, 1h, sl: 7, tp: 5, Close, -1.55, 0.11, -14.74, 54.76%
#  207 - sandusdt, 1h, sl: 7, tp: 9, Close, -5.13, 0.1, -49.5, 35.29%
#  208 - sandusdt, 1h, sl: 7, tp: 12, Close, -5.44, 0.1, -52.59, 30.30%
#  209 - sandusdt, 1h, sl: 1, tp: 3, Close, 0.87, 0.1, 8.89, 41.07%
#  210 - sandusdt, 1h, sl: 1, tp: 5, Close, 1.14, 0.1, 11.7, 31.48%
#  211 - sandusdt, 1h, sl: 1, tp: 9, Close, 0.83, 0.1, 8.54, 21.15%
#  212 - sandusdt, 1h, sl: 1, tp: 12, Close, 1.49, 0.1, 15.19, 19.23%
#  213 - sandusdt, 1h, sl: 3, tp: 3, Close, 0.45, 0.1, 4.63, 55.32%
#  214 - sandusdt, 1h, sl: 3, tp: 5, Close, 1.31, 0.1, 13.42, 48.89%
#  215 - sandusdt, 1h, sl: 3, tp: 9, Close, 0.25, 0.1, 2.56, 30.00%
#  216 - sandusdt, 1h, sl: 3, tp: 12, Close, 0.34, 0.1, 3.52, 25.64%
#  217 - sandusdt, 1h, sl: 5, tp: 3, Close, 0.23, 0.1, 2.37, 62.22%
#  218 - sandusdt, 1h, sl: 5, tp: 5, Close, 0.81, 0.1, 8.34, 54.76%
#  219 - sandusdt, 1h, sl: 5, tp: 9, Close, -1.46, 0.1, -15.15, 33.33%
#  220 - sandusdt, 1h, sl: 5, tp: 12, Close, -1.56, 0.1, -16.17, 28.57%
#  221 - sandusdt, 1h, sl: 7, tp: 3, Close, -0.31, 0.1, -3.2, 65.91%
#  222 - sandusdt, 1h, sl: 7, tp: 5, Close, -0.54, 0.1, -5.57, 56.10%
#  223 - sandusdt, 1h, sl: 7, tp: 9, Close, -3.95, 0.1, -41.42, 36.36%
#  224 - sandusdt, 1h, sl: 7, tp: 12, Close, -4.26, 0.1, -44.77, 31.25%
#  225 - sandusdt, 15m, sl: 1, tp: 3, Close, 0.67, 0.69, 0.97, 26.54%
#  226 - sandusdt, 15m, sl: 1, tp: 5, Close, -0.83, 0.69, -1.22, 17.89%
#  227 - sandusdt, 15m, sl: 1, tp: 9, Close, -0.29, 0.69, -0.42, 12.29%
#  228 - sandusdt, 15m, sl: 1, tp: 12, Close, -2.31, 0.68, -3.37, 10.07%
#  229 - sandusdt, 15m, sl: 3, tp: 3, Close, -0.23, 0.69, -0.33, 48.47%
#  230 - sandusdt, 15m, sl: 3, tp: 5, Close, -2.6, 0.68, -3.79, 34.60%
#  231 - sandusdt, 15m, sl: 3, tp: 9, Close, -2.75, 0.68, -4.01, 21.30%
#  232 - sandusdt, 15m, sl: 3, tp: 12, Close, -6.86, 0.68, -10.05, 14.56%
#  233 - sandusdt, 15m, sl: 5, tp: 3, Close, -1.18, 0.69, -1.72, 58.61%
#  234 - sandusdt, 15m, sl: 5, tp: 5, Close, -4.79, 0.68, -7.01, 44.39%
#  235 - sandusdt, 15m, sl: 5, tp: 9, Close, -6.29, 0.68, -9.23, 29.12%
#  236 - sandusdt, 15m, sl: 5, tp: 12, Close, -12.38, 0.68, -18.26, 20.93%
#  237 - sandusdt, 15m, sl: 7, tp: 3, Close, -0.7, 0.69, -1.02, 67.56%
#  238 - sandusdt, 15m, sl: 7, tp: 5, Close, -5.35, 0.68, -7.84, 54.21%
#  239 - sandusdt, 15m, sl: 7, tp: 9, Close, -5.19, 0.68, -7.61, 39.74%
#  240 - sandusdt, 15m, sl: 7, tp: 12, Close, -10.91, 0.68, -16.07, 26.76%
#  241 - sandusdt, 15m, sl: 1, tp: 3, Close, 1.03, 0.65, 1.58, 27.33%
#  242 - sandusdt, 15m, sl: 1, tp: 5, Close, -0.93, 0.65, -1.43, 18.60%
#  243 - sandusdt, 15m, sl: 1, tp: 9, Close, -0.15, 0.65, -0.23, 12.80%
#  244 - sandusdt, 15m, sl: 1, tp: 12, Close, -2.17, 0.65, -3.35, 10.49%
#  245 - sandusdt, 15m, sl: 3, tp: 3, Close, 0.06, 0.65, 0.09, 49.21%
#  246 - sandusdt, 15m, sl: 3, tp: 5, Close, -2.27, 0.65, -3.51, 35.65%
#  247 - sandusdt, 15m, sl: 3, tp: 9, Close, -2.01, 0.65, -3.11, 21.90%
#  248 - sandusdt, 15m, sl: 3, tp: 12, Close, -6.0, 0.65, -9.29, 14.50%
#  249 - sandusdt, 15m, sl: 5, tp: 3, Close, -0.83, 0.65, -1.28, 59.66%
#  250 - sandusdt, 15m, sl: 5, tp: 5, Close, -4.51, 0.65, -6.98, 45.67%
#  251 - sandusdt, 15m, sl: 5, tp: 9, Close, -5.22, 0.64, -8.1, 29.94%
#  252 - sandusdt, 15m, sl: 5, tp: 12, Close, -11.17, 0.64, -17.39, 21.56%
#  253 - sandusdt, 15m, sl: 7, tp: 3, Close, -0.72, 0.65, -1.12, 68.02%
#  254 - sandusdt, 15m, sl: 7, tp: 5, Close, -5.12, 0.65, -7.92, 55.08%
#  255 - sandusdt, 15m, sl: 7, tp: 9, Close, -4.25, 0.65, -6.58, 40.26%
#  256 - sandusdt, 15m, sl: 7, tp: 12, Close, -9.81, 0.64, -15.26, 27.14%
#  257 - woousdt, 1h, sl: 1, tp: 3, Close, -0.03, 0.02, -1.85, 28.81%
#  258 - woousdt, 1h, sl: 1, tp: 5, Close, -0.0, 0.02, -0.05, 21.05%
#  259 - woousdt, 1h, sl: 1, tp: 9, Close, -0.13, 0.02, -8.17, 12.96%
#  260 - woousdt, 1h, sl: 1, tp: 12, Close, -0.19, 0.02, -12.56, 11.32%
#  261 - woousdt, 1h, sl: 3, tp: 3, Close, -0.2, 0.02, -12.58, 46.30%
#  262 - woousdt, 1h, sl: 3, tp: 5, Close, -0.15, 0.02, -9.98, 34.04%
#  263 - woousdt, 1h, sl: 3, tp: 9, Close, -0.29, 0.02, -18.57, 16.28%
#  264 - woousdt, 1h, sl: 3, tp: 12, Close, -0.53, 0.02, -34.36, 9.76%
#  265 - woousdt, 1h, sl: 5, tp: 3, Close, -0.02, 0.02, -1.12, 66.67%
#  266 - woousdt, 1h, sl: 5, tp: 5, Close, 0.06, 0.02, 3.82, 55.81%
#  267 - woousdt, 1h, sl: 5, tp: 9, Close, 0.09, 0.02, 5.64, 35.29%
#  268 - woousdt, 1h, sl: 5, tp: 12, Close, -0.23, 0.02, -15.23, 19.35%
#  269 - woousdt, 1h, sl: 7, tp: 3, Close, 0.06, 0.02, 3.89, 75.51%
#  270 - woousdt, 1h, sl: 7, tp: 5, Close, 0.29, 0.02, 18.24, 65.00%
#  271 - woousdt, 1h, sl: 7, tp: 9, Close, 0.56, 0.02, 36.21, 41.38%
#  272 - woousdt, 1h, sl: 7, tp: 12, Close, 0.49, 0.02, 31.57, 24.00%
#  273 - woousdt, 1h, sl: 1, tp: 3, Close, -0.01, 0.01, -0.8, 28.57%
#  274 - woousdt, 1h, sl: 1, tp: 5, Close, 0.02, 0.01, 1.24, 21.82%
#  275 - woousdt, 1h, sl: 1, tp: 9, Close, -0.11, 0.01, -7.31, 13.46%
#  276 - woousdt, 1h, sl: 1, tp: 12, Close, -0.18, 0.01, -11.93, 11.76%
#  277 - woousdt, 1h, sl: 3, tp: 3, Close, -0.17, 0.01, -11.25, 47.06%
#  278 - woousdt, 1h, sl: 3, tp: 5, Close, -0.12, 0.01, -8.13, 35.56%
#  279 - woousdt, 1h, sl: 3, tp: 9, Close, -0.25, 0.01, -17.17, 17.07%
#  280 - woousdt, 1h, sl: 3, tp: 12, Close, -0.49, 0.01, -33.8, 10.26%
#  281 - woousdt, 1h, sl: 5, tp: 3, Close, 0.01, 0.01, 0.92, 67.35%
#  282 - woousdt, 1h, sl: 5, tp: 5, Close, 0.11, 0.01, 7.13, 57.14%
#  283 - woousdt, 1h, sl: 5, tp: 9, Close, 0.14, 0.01, 9.78, 36.36%
#  284 - woousdt, 1h, sl: 5, tp: 12, Close, -0.17, 0.01, -12.18, 20.00%
#  285 - woousdt, 1h, sl: 7, tp: 3, Close, 0.1, 0.01, 6.68, 76.60%
#  286 - woousdt, 1h, sl: 7, tp: 5, Close, 0.34, 0.01, 22.92, 66.67%
#  287 - woousdt, 1h, sl: 7, tp: 9, Close, 0.61, 0.01, 41.78, 42.86%
#  288 - woousdt, 1h, sl: 7, tp: 12, Close, 0.54, 0.01, 36.7, 25.00%
#  289 - woousdt, 15m, sl: 1, tp: 3, Close, -0.32, 0.09, -3.7, 28.97%
#  290 - woousdt, 15m, sl: 1, tp: 5, Close, -0.34, 0.09, -4.0, 19.29%
#  291 - woousdt, 15m, sl: 1, tp: 9, Close, -0.21, 0.09, -2.43, 12.31%
#  292 - woousdt, 15m, sl: 1, tp: 12, Close, -0.31, 0.09, -3.65, 11.11%
#  293 - woousdt, 15m, sl: 3, tp: 3, Close, -0.42, 0.09, -4.87, 48.54%
#  294 - woousdt, 15m, sl: 3, tp: 5, Close, -0.62, 0.09, -7.21, 34.09%
#  295 - woousdt, 15m, sl: 3, tp: 9, Close, -0.39, 0.09, -4.61, 21.21%
#  296 - woousdt, 15m, sl: 3, tp: 12, Close, -0.44, 0.09, -5.2, 18.42%
#  297 - woousdt, 15m, sl: 5, tp: 3, Close, -0.57, 0.09, -6.7, 62.91%
#  298 - woousdt, 15m, sl: 5, tp: 5, Close, -0.85, 0.09, -9.88, 49.18%
#  299 - woousdt, 15m, sl: 5, tp: 9, Close, -0.79, 0.09, -9.29, 32.05%
#  300 - woousdt, 15m, sl: 5, tp: 12, Close, -0.75, 0.09, -8.86, 25.00%
#  301 - woousdt, 15m, sl: 7, tp: 3, Close, -0.61, 0.09, -7.12, 71.64%
#  302 - woousdt, 15m, sl: 7, tp: 5, Close, -1.06, 0.09, -12.46, 58.08%
#  303 - woousdt, 15m, sl: 7, tp: 9, Close, -0.91, 0.09, -10.73, 42.86%
#  304 - woousdt, 15m, sl: 7, tp: 12, Close, -0.79, 0.09, -9.26, 34.40%
#  305 - woousdt, 15m, sl: 1, tp: 3, Close, -0.27, 0.08, -3.28, 29.75%
#  306 - woousdt, 15m, sl: 1, tp: 5, Close, -0.29, 0.08, -3.52, 20.07%
#  307 - woousdt, 15m, sl: 1, tp: 9, Close, -0.15, 0.08, -1.86, 12.84%
#  308 - woousdt, 15m, sl: 1, tp: 12, Close, -0.25, 0.08, -3.15, 11.60%
#  309 - woousdt, 15m, sl: 3, tp: 3, Close, -0.3, 0.08, -3.71, 49.57%
#  310 - woousdt, 15m, sl: 3, tp: 5, Close, -0.49, 0.08, -6.01, 34.88%
#  311 - woousdt, 15m, sl: 3, tp: 9, Close, -0.26, 0.08, -3.24, 21.76%
#  312 - woousdt, 15m, sl: 3, tp: 12, Close, -0.31, 0.08, -3.87, 18.92%
#  313 - woousdt, 15m, sl: 5, tp: 3, Close, -0.46, 0.08, -5.63, 63.77%
#  314 - woousdt, 15m, sl: 5, tp: 5, Close, -0.62, 0.08, -7.69, 50.28%
#  315 - woousdt, 15m, sl: 5, tp: 9, Close, -0.55, 0.08, -6.87, 32.89%
#  316 - woousdt, 15m, sl: 5, tp: 12, Close, -0.52, 0.08, -6.42, 25.69%
#  317 - woousdt, 15m, sl: 7, tp: 3, Close, -0.47, 0.08, -5.85, 72.82%
#  318 - woousdt, 15m, sl: 7, tp: 5, Close, -0.85, 0.08, -10.47, 58.90%
#  319 - woousdt, 15m, sl: 7, tp: 9, Close, -0.69, 0.08, -8.59, 43.08%
#  320 - woousdt, 15m, sl: 7, tp: 12, Close, -0.48, 0.08, -6.01, 35.25%
#  321 - dydxusdt, 1h, sl: 1, tp: 3, Close, -2.32, 0.47, -4.94, 29.33%
#  322 - dydxusdt, 1h, sl: 1, tp: 5, Close, -6.93, 0.47, -14.8, 15.71%
#  323 - dydxusdt, 1h, sl: 1, tp: 9, Close, -4.27, 0.47, -9.1, 10.45%
#  324 - dydxusdt, 1h, sl: 1, tp: 12, Close, -6.12, 0.47, -13.07, 7.81%
#  325 - dydxusdt, 1h, sl: 3, tp: 3, Close, 0.62, 0.47, 1.33, 53.33%
#  326 - dydxusdt, 1h, sl: 3, tp: 5, Close, -12.47, 0.46, -26.91, 35.29%
#  327 - dydxusdt, 1h, sl: 3, tp: 9, Close, -9.61, 0.46, -20.68, 20.83%
#  328 - dydxusdt, 1h, sl: 3, tp: 12, Close, -13.54, 0.46, -29.25, 11.36%
#  329 - dydxusdt, 1h, sl: 5, tp: 3, Close, -9.0, 0.46, -19.37, 59.65%
#  330 - dydxusdt, 1h, sl: 5, tp: 5, Close, -26.57, 0.46, -58.25, 45.83%
#  331 - dydxusdt, 1h, sl: 5, tp: 9, Close, -24.56, 0.46, -53.72, 28.89%
#  332 - dydxusdt, 1h, sl: 5, tp: 12, Close, -29.29, 0.45, -64.39, 19.51%
#  333 - dydxusdt, 1h, sl: 7, tp: 3, Close, -13.88, 0.46, -30.0, 63.64%
#  334 - dydxusdt, 1h, sl: 7, tp: 5, Close, -44.04, 0.45, -98.42, 51.11%
#  335 - dydxusdt, 1h, sl: 7, tp: 9, Close, -39.24, 0.45, -87.22, 38.46%
#  336 - dydxusdt, 1h, sl: 7, tp: 12, Close, -56.01, 0.44, -126.87, 23.53%
#  337 - dydxusdt, 1h, sl: 1, tp: 3, Close, -3.54, 0.43, -8.15, 26.76%
#  338 - dydxusdt, 1h, sl: 1, tp: 5, Close, -8.76, 0.43, -20.32, 13.64%
#  339 - dydxusdt, 1h, sl: 1, tp: 9, Close, -7.42, 0.43, -17.18, 9.38%
#  340 - dydxusdt, 1h, sl: 1, tp: 12, Close, -7.91, 0.43, -18.33, 8.06%
#  341 - dydxusdt, 1h, sl: 3, tp: 3, Close, -0.12, 0.43, -0.27, 51.79%
#  342 - dydxusdt, 1h, sl: 3, tp: 5, Close, -13.72, 0.43, -32.16, 34.04%
#  343 - dydxusdt, 1h, sl: 3, tp: 9, Close, -12.09, 0.43, -28.3, 20.00%
#  344 - dydxusdt, 1h, sl: 3, tp: 12, Close, -14.24, 0.43, -33.39, 11.90%
#  345 - dydxusdt, 1h, sl: 5, tp: 3, Close, -9.46, 0.43, -22.07, 58.49%
#  346 - dydxusdt, 1h, sl: 5, tp: 5, Close, -27.34, 0.42, -65.13, 45.45%
#  347 - dydxusdt, 1h, sl: 5, tp: 9, Close, -26.44, 0.42, -62.92, 28.57%
#  348 - dydxusdt, 1h, sl: 5, tp: 12, Close, -28.73, 0.42, -68.54, 20.51%
#  349 - dydxusdt, 1h, sl: 7, tp: 3, Close, -13.66, 0.43, -32.01, 64.00%
#  350 - dydxusdt, 1h, sl: 7, tp: 5, Close, -44.07, 0.41, -107.11, 52.50%
#  351 - dydxusdt, 1h, sl: 7, tp: 9, Close, -40.11, 0.41, -97.02, 40.00%
#  352 - dydxusdt, 1h, sl: 7, tp: 12, Close, -52.63, 0.41, -129.26, 25.81%
#  353 - dydxusdt, 15m, sl: 1, tp: 3, Close, -4.27, 2.0, -2.13, 31.19%
#  354 - dydxusdt, 15m, sl: 1, tp: 5, Close, -5.61, 2.0, -2.81, 19.83%
#  355 - dydxusdt, 15m, sl: 1, tp: 9, Close, 0.0, 2.0, 0.0, 15.25%
#  356 - dydxusdt, 15m, sl: 1, tp: 12, Close, -0.83, 2.0, -0.42, 14.24%
#  357 - dydxusdt, 15m, sl: 3, tp: 3, Close, -1.01, 2.0, -0.5, 55.52%
#  358 - dydxusdt, 15m, sl: 3, tp: 5, Close, -12.35, 2.0, -6.19, 35.06%
#  359 - dydxusdt, 15m, sl: 3, tp: 9, Close, -3.2, 2.0, -1.6, 23.24%
#  360 - dydxusdt, 15m, sl: 3, tp: 12, Close, -9.77, 2.0, -4.9, 18.42%
#  361 - dydxusdt, 15m, sl: 5, tp: 3, Close, -2.6, 2.0, -1.3, 67.11%
#  362 - dydxusdt, 15m, sl: 5, tp: 5, Close, -8.61, 2.0, -4.31, 47.26%
#  363 - dydxusdt, 15m, sl: 5, tp: 9, Close, 6.34, 2.0, 3.17, 31.28%
#  364 - dydxusdt, 15m, sl: 5, tp: 12, Close, -1.31, 2.0, -0.66, 24.02%
#  365 - dydxusdt, 15m, sl: 7, tp: 3, Close, -6.16, 2.0, -3.08, 71.13%
#  366 - dydxusdt, 15m, sl: 7, tp: 5, Close, -18.01, 1.99, -9.03, 52.51%
#  367 - dydxusdt, 15m, sl: 7, tp: 9, Close, -8.96, 2.0, -4.49, 36.26%
#  368 - dydxusdt, 15m, sl: 7, tp: 12, Close, -21.39, 1.99, -10.75, 27.92%
#  369 - dydxusdt, 15m, sl: 1, tp: 3, Close, -4.26, 1.88, -2.26, 30.85%
#  370 - dydxusdt, 15m, sl: 1, tp: 5, Close, -4.7, 1.88, -2.49, 20.40%
#  371 - dydxusdt, 15m, sl: 1, tp: 9, Close, 1.27, 1.88, 0.68, 15.71%
#  372 - dydxusdt, 15m, sl: 1, tp: 12, Close, 0.55, 1.88, 0.29, 14.69%
#  373 - dydxusdt, 15m, sl: 3, tp: 3, Close, -0.98, 1.88, -0.52, 55.52%
#  374 - dydxusdt, 15m, sl: 3, tp: 5, Close, -10.07, 1.88, -5.36, 36.23%
#  375 - dydxusdt, 15m, sl: 3, tp: 9, Close, -1.24, 1.88, -0.66, 24.36%
#  376 - dydxusdt, 15m, sl: 3, tp: 12, Close, -7.48, 1.88, -3.98, 19.46%
#  377 - dydxusdt, 15m, sl: 5, tp: 3, Close, -2.55, 1.88, -1.35, 66.78%
#  378 - dydxusdt, 15m, sl: 5, tp: 5, Close, -7.69, 1.88, -4.09, 48.05%
#  379 - dydxusdt, 15m, sl: 5, tp: 9, Close, 6.52, 1.89, 3.46, 31.58%
#  380 - dydxusdt, 15m, sl: 5, tp: 12, Close, -1.41, 1.88, -0.75, 23.56%
#  381 - dydxusdt, 15m, sl: 7, tp: 3, Close, -6.38, 1.88, -3.39, 70.76%
#  382 - dydxusdt, 15m, sl: 7, tp: 5, Close, -16.94, 1.88, -9.03, 53.02%
#  383 - dydxusdt, 15m, sl: 7, tp: 9, Close, -9.54, 1.88, -5.08, 36.31%
#  384 - dydxusdt, 15m, sl: 7, tp: 12, Close, -22.52, 1.87, -12.03, 27.15%
#  385 - atomusdt, 1h, sl: 1, tp: 3, Close, -13.83, 1.65, -8.38, 27.06%
#  386 - atomusdt, 1h, sl: 1, tp: 5, Close, -15.9, 1.65, -9.64, 17.07%
#  387 - atomusdt, 1h, sl: 1, tp: 9, Close, -22.94, 1.65, -13.94, 12.50%
#  388 - atomusdt, 1h, sl: 1, tp: 12, Close, -24.02, 1.65, -14.6, 11.54%
#  389 - atomusdt, 1h, sl: 3, tp: 3, Close, -31.99, 1.64, -19.49, 44.59%
#  390 - atomusdt, 1h, sl: 3, tp: 5, Close, -36.42, 1.64, -22.22, 32.84%
#  391 - atomusdt, 1h, sl: 3, tp: 9, Close, -39.99, 1.64, -24.43, 22.22%
#  392 - atomusdt, 1h, sl: 3, tp: 12, Close, -49.29, 1.63, -30.19, 11.67%
#  393 - atomusdt, 1h, sl: 5, tp: 3, Close, -44.67, 1.63, -27.32, 52.17%
#  394 - atomusdt, 1h, sl: 5, tp: 5, Close, -53.23, 1.63, -32.64, 39.34%
#  395 - atomusdt, 1h, sl: 5, tp: 9, Close, -78.76, 1.62, -48.68, 25.45%
#  396 - atomusdt, 1h, sl: 5, tp: 12, Close, -81.35, 1.62, -50.32, 15.38%
#  397 - atomusdt, 1h, sl: 7, tp: 3, Close, -42.89, 1.64, -26.22, 58.73%
#  398 - atomusdt, 1h, sl: 7, tp: 5, Close, -64.98, 1.62, -39.99, 48.15%
#  399 - atomusdt, 1h, sl: 7, tp: 9, Close, -103.5, 1.61, -64.47, 34.04%
#  400 - atomusdt, 1h, sl: 7, tp: 12, Close, -111.47, 1.56, -71.48, 21.43%
#  401 - atomusdt, 1h, sl: 1, tp: 3, Close, -13.91, 1.51, -9.22, 25.61%
#  402 - atomusdt, 1h, sl: 1, tp: 5, Close, -14.76, 1.51, -9.79, 17.72%
#  403 - atomusdt, 1h, sl: 1, tp: 9, Close, -22.48, 1.5, -14.95, 12.99%
#  404 - atomusdt, 1h, sl: 1, tp: 12, Close, -24.07, 1.5, -16.01, 12.00%
#  405 - atomusdt, 1h, sl: 3, tp: 3, Close, -32.08, 1.5, -21.39, 43.66%
#  406 - atomusdt, 1h, sl: 3, tp: 5, Close, -34.34, 1.5, -22.92, 32.31%
#  407 - atomusdt, 1h, sl: 3, tp: 9, Close, -40.0, 1.5, -26.75, 21.31%
#  408 - atomusdt, 1h, sl: 3, tp: 12, Close, -47.78, 1.49, -32.04, 12.07%
#  409 - atomusdt, 1h, sl: 5, tp: 3, Close, -41.94, 1.49, -28.07, 51.52%
#  410 - atomusdt, 1h, sl: 5, tp: 5, Close, -47.21, 1.49, -31.65, 38.98%
#  411 - atomusdt, 1h, sl: 5, tp: 9, Close, -74.85, 1.48, -50.65, 24.53%
#  412 - atomusdt, 1h, sl: 5, tp: 12, Close, -75.51, 1.48, -51.1, 16.00%
#  413 - atomusdt, 1h, sl: 7, tp: 3, Close, -39.13, 1.5, -26.16, 58.33%
#  414 - atomusdt, 1h, sl: 7, tp: 5, Close, -56.75, 1.49, -38.17, 48.08%
#  415 - atomusdt, 1h, sl: 7, tp: 9, Close, -97.4, 1.47, -66.41, 33.33%
#  416 - atomusdt, 1h, sl: 7, tp: 12, Close, -103.32, 1.42, -72.67, 22.50%
#  417 - atomusdt, 15m, sl: 1, tp: 3, Close, -20.88, 7.78, -2.68, 27.72%
#  418 - atomusdt, 15m, sl: 1, tp: 5, Close, -11.39, 7.79, -1.46, 20.00%
#  419 - atomusdt, 15m, sl: 1, tp: 9, Close, -14.04, 7.79, -1.8, 14.41%
#  420 - atomusdt, 15m, sl: 1, tp: 12, Close, -12.05, 7.79, -1.55, 12.96%
#  421 - atomusdt, 15m, sl: 3, tp: 3, Close, -32.21, 7.78, -4.14, 49.50%
#  422 - atomusdt, 15m, sl: 3, tp: 5, Close, -13.5, 7.79, -1.73, 34.94%
#  423 - atomusdt, 15m, sl: 3, tp: 9, Close, -33.74, 7.75, -4.36, 20.00%
#  424 - atomusdt, 15m, sl: 3, tp: 12, Close, -55.52, 7.74, -7.18, 14.68%
#  425 - atomusdt, 15m, sl: 5, tp: 3, Close, -43.7, 7.77, -5.62, 61.59%
#  426 - atomusdt, 15m, sl: 5, tp: 5, Close, -26.5, 7.78, -3.4, 47.83%
#  427 - atomusdt, 15m, sl: 5, tp: 9, Close, -48.27, 7.73, -6.24, 28.57%
#  428 - atomusdt, 15m, sl: 5, tp: 12, Close, -86.01, 7.71, -11.16, 19.88%
#  429 - atomusdt, 15m, sl: 7, tp: 3, Close, -50.13, 7.77, -6.45, 66.04%
#  430 - atomusdt, 15m, sl: 7, tp: 5, Close, -43.1, 7.77, -5.54, 53.95%
#  431 - atomusdt, 15m, sl: 7, tp: 9, Close, -106.67, 7.7, -13.85, 33.74%
#  432 - atomusdt, 15m, sl: 7, tp: 12, Close, -125.33, 7.69, -16.3, 24.83%
#  433 - atomusdt, 15m, sl: 1, tp: 3, Close, -19.2, 7.39, -2.6, 28.37%
#  434 - atomusdt, 15m, sl: 1, tp: 5, Close, -9.63, 7.39, -1.3, 20.41%
#  435 - atomusdt, 15m, sl: 1, tp: 9, Close, -12.19, 7.39, -1.65, 14.60%
#  436 - atomusdt, 15m, sl: 1, tp: 12, Close, -10.42, 7.39, -1.41, 13.10%
#  437 - atomusdt, 15m, sl: 3, tp: 3, Close, -30.02, 7.38, -4.07, 51.03%
#  438 - atomusdt, 15m, sl: 3, tp: 5, Close, -10.95, 7.39, -1.48, 36.05%
#  439 - atomusdt, 15m, sl: 3, tp: 9, Close, -28.81, 7.35, -3.92, 20.91%
#  440 - atomusdt, 15m, sl: 3, tp: 12, Close, -49.88, 7.34, -6.79, 15.38%
#  441 - atomusdt, 15m, sl: 5, tp: 3, Close, -42.31, 7.38, -5.73, 62.22%
#  442 - atomusdt, 15m, sl: 5, tp: 5, Close, -25.9, 7.39, -3.51, 48.20%
#  443 - atomusdt, 15m, sl: 5, tp: 9, Close, -45.57, 7.33, -6.21, 28.98%
#  444 - atomusdt, 15m, sl: 5, tp: 12, Close, -83.8, 7.31, -11.46, 20.00%
#  445 - atomusdt, 15m, sl: 7, tp: 3, Close, -48.39, 7.37, -6.56, 66.67%
#  446 - atomusdt, 15m, sl: 7, tp: 5, Close, -38.84, 7.38, -5.26, 54.81%
#  447 - atomusdt, 15m, sl: 7, tp: 9, Close, -92.83, 7.31, -12.7, 33.96%
#  448 - atomusdt, 15m, sl: 7, tp: 12, Close, -119.29, 7.3, -16.35, 24.82%
# Time taken to execute for loop: 1028.6487033367157 seconds

# %%
results_df.to_csv(f'results_df_007.csv')
