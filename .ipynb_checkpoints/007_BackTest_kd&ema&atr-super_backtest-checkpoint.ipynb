# %%
# k crossover d，close > ema 8, ema 8 > ema 18, ema 18 > 38, take profit atr, stop loss atr
# Variables :
# time - 15m, 1h
# start time - 1609459200000, 1641028611000, 1672564611000 (2021, 2022, 2023)
# tp atr - 4, 6
# sl atr - 3, 5
# sl - Close, Low

# %%
# ! conda install -c conda-forge ta --yes

# %%
import requests
import pandas as pd
import ta
import datetime as dt
import numpy as np
import time
import itertools

# %%
start_time_arr = [1672531200000, 1641028611000, 1609459200000]

interval_arr = ['15m', '1h']

# how kd is crossed
kd_dir_arr = ['Any', 'Up']

sl_atr_arr = [1, 2, 3]

tp_atr_arr = [6, 8, 10]

# stop loss determine candlestick
sl_det_arr = ['Close', 'Low']

# %%
timezone = 8
endpoint = 'wss://stream.binance.com:9443/ws'
symbol = 'ethusdt'
symbol_C = symbol.upper()

end_time = round(time.time() * 1000)

# step between timestamps in milliseconds
step = 60000 * 3600

# %%
def create_raw(symbol, interval_arr, start_time, end_time, step):
    
    url = "https://api.binance.com/api/v3/klines"
    
    for interval in interval_arr:

        raw_df = pd.DataFrame()
        
        for timestamp in range(start_time, end_time, step):
            params = {"symbol": symbol_C,
                      "interval": interval,
                      "startTime": timestamp,
                      "endTime": timestamp + step}
            response = requests.get(url, params=params).json()
            out = pd.DataFrame(response, columns = ["Open time", "Open", "High", "Low", "Close",
                                                   "Volume", "Close_Time", "Quote asset volume",
                                                   "Number of trades", "Taker buy base asset volume",
                                                   "Taker buy quote asset volume", "Ignore"])
            raw_df = pd.concat([raw_df, out], axis = 0)

        raw_df = raw_df[['Close_Time', 'Open', 'Close', "High", "Low", 'Volume']]

        raw_df.to_hdf(f'klines_{symbol}_{interval}.h5', key='df', mode='w')

# %%
loop_start_time = time.time()
create_raw(symbol, interval_arr, min(start_time_arr), end_time, step)
loop_end_time = time.time()
print("Time taken to execute for loop:", loop_end_time - loop_start_time, "seconds")
# Out:
# Time taken to execute for loop: 75.8189640045166 seconds

# %%
klines_cache = {}

def get_klines(symbol, interval, start_time, end_time, step):
    if (symbol, interval) not in klines_cache:
        klines_cache[(symbol, interval)] = pd.read_hdf(f'klines_{symbol}_{interval}.h5', key='df')

    df = klines_cache[(symbol, interval)].query(f"Close_Time >= {start_time} and Close_Time <= {end_time}")

    df = df[['Close_Time', 'Open', 'Close', "High", "Low", 'Volume']].astype(float)

    df['Close_Time'] = pd.to_datetime(df['Close_Time'], unit='ms') + pd.Timedelta(hours=timezone)
    df['Close_Time'] = df['Close_Time'].dt.strftime('%Y-%m-%d %H:%M:%S')
    
    df = df.reset_index(drop=True)

    return df

# %%
def check_cross(df, kd_dir):
    up = df['slow_k'] > df['slow_d']
    down = df['slow_k'] < df['slow_d']
    if kd_dir == 'Up':
        return up.diff() & up
    if kd_dir == 'Any':
        return up.diff()
    if kd_dir == 'Down':
        return down.diff() & down


def indicators(df, kd_dir):

# ema
    for i in (8, 18, 38):
        df['ema_'+str(i)] = ta.trend.ema_indicator(df.Close, window=i)

# atr
    df['atr'] = ta.volatility.average_true_range(df.High, df.Low, df.Close)
    
# rsi
    rsi_int = 14
    df['rsi'] = ta.momentum.RSIIndicator(df['Close'], window = rsi_int).rsi()

# kd
    kd_int = 14
    d_int = 3
   
    kd_df = pd.DataFrame()
    kd_df[str(kd_int) + '-Low'] = df['Low'].rolling(kd_int).min()
    kd_df[str(kd_int) + '-High'] = df['High'].rolling(kd_int).max()
    df['slow_k'] = (df['Close'] - kd_df[str(kd_int) + '-Low'])*100/(kd_df[str(kd_int) + '-High'] - kd_df[str(kd_int) + '-Low'])
    df['slow_d'] = df['slow_k'].rolling(d_int).mean()
    
# kd cross
    df['kd_cross'] = check_cross(df, kd_dir)

# %%
def conditions(df):

    for index, row in df.iterrows():
        # c1
        df['c1'] = df['kd_cross']
        # c2
        df['c2'] = df['Close'] >= df['ema_8']
        # c3
        df['c3'] = df['ema_8'] >= df['ema_18']
        # c4
        df['c4'] = df['ema_18'] >= df['ema_38']

    # 條件達成
    df['signal'] = False
    df.loc[df.c1 & df.c2 & df.c3 & df.c4 , 'signal'] = True


    # 下一根進場
    df['open_entry'] = False
    for i in range(len(df) - 1):
        if df.loc[i, 'signal'] == True:
            df.loc[i + 1, 'open_entry'] = True

# %%
def entries(df, sl_atr, tp_atr, sl_det):

    in_position = False
    stop_loss = np.nan
    take_profit = np.nan
    close_val = df['Close']
    atr_val = df['atr']

    for index, row in df.iterrows():

        if index == 0:
            continue

        elif df.at[index, 'open_entry'] == True:

            df.at[index, 'entry_p'] = close_val.shift(1).at[index]
            df.at[index, 'stop_loss'] = close_val.shift(1).at[index] - sl_atr * atr_val.shift(1).at[index]
            df.at[index, 'take_profit'] = close_val.shift(1).at[index] + tp_atr * atr_val.shift(1).at[index]
            df.at[index, 'position'] = 'Buy'
            in_position = True
            stop_loss = df.at[index, 'stop_loss']
            take_profit = df.at[index, 'take_profit']


        # 吃筍
        #-----------------------------重要-----------------------------
        # 若用 if 寫，則有可能入場馬上吃筍，若用 elif 則一個 iteration 只會執行一次
        elif in_position == True and (df.at[index, sl_det] <= stop_loss):
            df.at[index, 'position'] = 'Stop'
            in_position = False
            stop_loss = np.nan
            take_profit = np.nan

        # set take profit
        elif in_position == True and (df.at[index, 'High'] >= take_profit):
            df.at[index, 'position'] = 'Sell'
            in_position = False
            stop_loss = np.nan
            take_profit = np.nan
    

    # 過濾有訊號或事件發生的Ｋ線
    df = df[(df['open_entry'] == True) |
                  (df['signal'] == True) | 
                  (df['position'] == 'Buy') |
                  (df['position'] == 'Sell') |
                  (df['position'] == 'Stop')]

# %%
# 部位回測
def backtest(df):

    df = df.reset_index(drop = True)
    df = df[(df['position'] == 'Buy') |
                  (df['position'] == 'Sell') |
                  (df['position'] == 'Stop')]

    # 一次進場多少單位
    pos_size = 1

    col = ['Close_Time', 'Open', 'Close', 'High', 'Low', 'ema_8', 'ema_18', 'ema_38', 'atr', 'kd_cross', 'position','entry_p', 'stop_loss', 'take_profit']
    pos = df[col]
    pos = pos.reset_index(drop = True)


    for index, row in pos.iterrows():

        current_pos = 0

        # 進場
        if pos.at[index, 'position'] == 'Buy':
            pos.at[index, 'size'] = pos_size
            pos.exit_p = np.nan

        # 出場
        if pos.at[index, 'position'] == 'Sell' or pos.at[index, 'position'] == 'Stop':

            # 停利：達成條件時收盤價
            if pos.at[index, 'position'] == 'Sell':
                for i in range(index -1, -1, -1):
                    if pos.at[i, 'position'] == 'Buy':
                        pos.at[index, 'exit_p'] = pos.at[i, 'take_profit']
                    break

            # 停損：打到進場停損點（往回跌代，直到最近的'Buy'及其'stop_loss'）
            if pos.at[index, 'position'] == 'Stop':
                for i in range(index -1, -1, -1):
                    if pos.at[i, 'position'] == 'Buy':
                        pos.at[index, 'exit_p'] = pos.at[i, 'stop_loss']
                    break

            # 計算每次出場部位大小（每次出場皆清倉）
            for i in range(index -1, -1, -1):
                if pos.at[i, 'position'] == 'Buy':
                    current_pos += pos.at[i, 'size']
                    if i == 0:
                        pos.at[index, 'size'] = -current_pos
                    else:
                        continue
                else:
                    pos.at[index, 'size'] = -current_pos
                    current_pos = 0
                    break


    # 計算部位價值
    for index, row in pos.iterrows():
        if pos.at[index, 'position'] == 'Buy':
            pos.at[index, 'amt'] = round(pos.at[index, 'size'] * pos.at[index, 'entry_p'], 4)
        elif pos.at[index, 'position'] == 'Sell' or pos.at[index, 'position'] == 'Stop':
            pos.at[index, 'amt'] = round(pos.at[index, 'size'] * pos.at[index, 'exit_p'], 4)


    # 若最後一筆為 Buy，移除該單，迭代驗證
    for index, row in pos.iloc[::-1].iterrows():
        if row['position'] == 'Buy':
            pos = pos.drop(index)
        else:
            break


    # 手續費、滑點、價差
    fee = 0.05 / 100
    amt_abs_sum = pos.amt.abs().sum()
    ttl_fee = amt_abs_sum * fee

    # 損益
    leverage = 10
    ttl_profit = -pos.amt.sum() - ttl_fee


    # 計算進場最大部位，最大損益
    consec_entry = 0
    position_amt_sum = 0
    max_consec_entry = 0
    max_position = 0
    max_profit = 0
    max_loss = 0

    for index, row in pos.iterrows():

        if row['position'] == 'Buy':

            consec_entry += 1
            position_amt_sum += row['amt']

        elif row['position'] in ['Sell', 'Stop']:

            if consec_entry > max_consec_entry:
                max_consec_entry = consec_entry
                max_position = position_amt_sum

            position_amt_sum += row['amt']

            if -position_amt_sum > max_profit:
                max_profit = -position_amt_sum

            if -position_amt_sum < max_loss:
                max_loss = -position_amt_sum

            consec_entry = 0
            position_amt_sum = 0

        else:
            pass


    profit_per = "{:.2f}%".format(ttl_profit / (max_position/leverage) * 100)

    wins = pos['position'].str.count('Sell').sum()
    loses = pos['position'].str.count('Stop').sum()

    win_rate = "{:.2f}%".format(wins / (wins + loses) * 100)

    result = {'Profit': [round(ttl_profit, 2)],
              'Fee': [round(ttl_fee, 2)],
              'Max_Profit': [round(max_profit, 2)],
              'Max_Loss': [round(max_loss, 2)],
              'Max_Entry': [max_consec_entry],
              'Max_Position': [round(max_position, 2)],
              'Profit_%': [profit_per],
              'Win_Rate': [win_rate]}


    result_df = pd.DataFrame(result)

    return result_df

# %%
# iterate using start_time, under same time interval, test different variables
def run_backtest():

    results_df = pd.DataFrame()

    start_time_list = []
    interval_list = []
    kd_dir_list = []
    sl_atr_list = []
    tp_atr_list = []
    sl_det_list = []

    i = 0

    loop_start_time = time.time()
    
    parameters = [(start_time, interval, kd_dir, sl_atr, tp_atr, sl_det) 
                  for start_time in start_time_arr
                  for interval in interval_arr
                  for kd_dir in kd_dir_arr
                  for sl_atr in sl_atr_arr
                  for tp_atr in tp_atr_arr
                  for sl_det in sl_det_arr]
    
    for start_time, interval, kd_dir, sl_atr, tp_atr, sl_det in parameters:

        df = get_klines(symbol, interval, start_time, end_time, step)

        indicators(df, kd_dir)
        conditions(df)
        entries(df, sl_atr, tp_atr, sl_det)
        results_df = pd.concat([results_df, backtest(df)], ignore_index = True)

        start_time_list.append(start_time)
        interval_list.append(interval)
        kd_dir_list.append(kd_dir)
        sl_atr_list.append(sl_atr)
        tp_atr_list.append(tp_atr)
        sl_det_list.append(sl_det)

        i += 1

        print(f" iteration # {i} is done - {start_time}, {interval}, {kd_dir}, {sl_det}")

    loop_end_time = time.time()

    print("Time taken to execute for loop:", loop_end_time - loop_start_time, "seconds")

    results_df['start_time'] = start_time_list
    results_df['interval'] = interval_list
    results_df['kd_dir'] = kd_dir_list
    results_df['sl_atr'] = sl_atr_list
    results_df['tp_atr'] = tp_atr_list
    results_df['sl_det'] = sl_det_list

    results_df = results_df[['start_time', 'interval', 'kd_dir',
                             'sl_atr', 'tp_atr', 'sl_det',
                             'Profit', 'Fee', 'Max_Profit', 'Max_Loss',
                             'Max_Entry', 'Max_Position', 'Profit_%'
                            ]]
    
    return results_df

# %%
results_df = run_backtest()
results_df = results_df.sort_values('Profit', ascending = False)
print(results_df)
# Out:
#  iteration # 1 is done - 1672531200000, 15m, Any, Close
#  iteration # 2 is done - 1672531200000, 15m, Any, Low
#  iteration # 3 is done - 1672531200000, 15m, Any, Close
#  iteration # 4 is done - 1672531200000, 15m, Any, Low
#  iteration # 5 is done - 1672531200000, 15m, Any, Close
#  iteration # 6 is done - 1672531200000, 15m, Any, Low
#  iteration # 7 is done - 1672531200000, 15m, Any, Close
#  iteration # 8 is done - 1672531200000, 15m, Any, Low
#  iteration # 9 is done - 1672531200000, 15m, Any, Close
#  iteration # 10 is done - 1672531200000, 15m, Any, Low
#  iteration # 11 is done - 1672531200000, 15m, Any, Close
#  iteration # 12 is done - 1672531200000, 15m, Any, Low
#  iteration # 13 is done - 1672531200000, 15m, Any, Close
#  iteration # 14 is done - 1672531200000, 15m, Any, Low
#  iteration # 15 is done - 1672531200000, 15m, Any, Close
#  iteration # 16 is done - 1672531200000, 15m, Any, Low
#  iteration # 17 is done - 1672531200000, 15m, Any, Close
#  iteration # 18 is done - 1672531200000, 15m, Any, Low
#  iteration # 19 is done - 1672531200000, 15m, Up, Close
#  iteration # 20 is done - 1672531200000, 15m, Up, Low
#  iteration # 21 is done - 1672531200000, 15m, Up, Close
#  iteration # 22 is done - 1672531200000, 15m, Up, Low
#  iteration # 23 is done - 1672531200000, 15m, Up, Close
#  iteration # 24 is done - 1672531200000, 15m, Up, Low
#  iteration # 25 is done - 1672531200000, 15m, Up, Close
#  iteration # 26 is done - 1672531200000, 15m, Up, Low
#  iteration # 27 is done - 1672531200000, 15m, Up, Close
#  iteration # 28 is done - 1672531200000, 15m, Up, Low
#  iteration # 29 is done - 1672531200000, 15m, Up, Close
#  iteration # 30 is done - 1672531200000, 15m, Up, Low
#  iteration # 31 is done - 1672531200000, 15m, Up, Close
#  iteration # 32 is done - 1672531200000, 15m, Up, Low
#  iteration # 33 is done - 1672531200000, 15m, Up, Close
#  iteration # 34 is done - 1672531200000, 15m, Up, Low
#  iteration # 35 is done - 1672531200000, 15m, Up, Close
#  iteration # 36 is done - 1672531200000, 15m, Up, Low
#  iteration # 37 is done - 1672531200000, 1h, Any, Close
#  iteration # 38 is done - 1672531200000, 1h, Any, Low
#  iteration # 39 is done - 1672531200000, 1h, Any, Close
#  iteration # 40 is done - 1672531200000, 1h, Any, Low
#  iteration # 41 is done - 1672531200000, 1h, Any, Close
#  iteration # 42 is done - 1672531200000, 1h, Any, Low
#  iteration # 43 is done - 1672531200000, 1h, Any, Close
#  iteration # 44 is done - 1672531200000, 1h, Any, Low
#  iteration # 45 is done - 1672531200000, 1h, Any, Close
#  iteration # 46 is done - 1672531200000, 1h, Any, Low
#  iteration # 47 is done - 1672531200000, 1h, Any, Close
#  iteration # 48 is done - 1672531200000, 1h, Any, Low
#  iteration # 49 is done - 1672531200000, 1h, Any, Close
#  iteration # 50 is done - 1672531200000, 1h, Any, Low
#  iteration # 51 is done - 1672531200000, 1h, Any, Close
#  iteration # 52 is done - 1672531200000, 1h, Any, Low
#  iteration # 53 is done - 1672531200000, 1h, Any, Close
#  iteration # 54 is done - 1672531200000, 1h, Any, Low
#  iteration # 55 is done - 1672531200000, 1h, Up, Close
#  iteration # 56 is done - 1672531200000, 1h, Up, Low
#  iteration # 57 is done - 1672531200000, 1h, Up, Close
#  iteration # 58 is done - 1672531200000, 1h, Up, Low
#  iteration # 59 is done - 1672531200000, 1h, Up, Close
#  iteration # 60 is done - 1672531200000, 1h, Up, Low
#  iteration # 61 is done - 1672531200000, 1h, Up, Close
#  iteration # 62 is done - 1672531200000, 1h, Up, Low
#  iteration # 63 is done - 1672531200000, 1h, Up, Close
#  iteration # 64 is done - 1672531200000, 1h, Up, Low
#  iteration # 65 is done - 1672531200000, 1h, Up, Close
#  iteration # 66 is done - 1672531200000, 1h, Up, Low
#  iteration # 67 is done - 1672531200000, 1h, Up, Close
#  iteration # 68 is done - 1672531200000, 1h, Up, Low
#  iteration # 69 is done - 1672531200000, 1h, Up, Close
#  iteration # 70 is done - 1672531200000, 1h, Up, Low
#  iteration # 71 is done - 1672531200000, 1h, Up, Close
#  iteration # 72 is done - 1672531200000, 1h, Up, Low
#  iteration # 73 is done - 1641028611000, 15m, Any, Close
#  iteration # 74 is done - 1641028611000, 15m, Any, Low
#  iteration # 75 is done - 1641028611000, 15m, Any, Close
#  iteration # 76 is done - 1641028611000, 15m, Any, Low
#  iteration # 77 is done - 1641028611000, 15m, Any, Close
#  iteration # 78 is done - 1641028611000, 15m, Any, Low
#  iteration # 79 is done - 1641028611000, 15m, Any, Close
#  iteration # 80 is done - 1641028611000, 15m, Any, Low
#  iteration # 81 is done - 1641028611000, 15m, Any, Close
#  iteration # 82 is done - 1641028611000, 15m, Any, Low
#  iteration # 83 is done - 1641028611000, 15m, Any, Close
#  iteration # 84 is done - 1641028611000, 15m, Any, Low
#  iteration # 85 is done - 1641028611000, 15m, Any, Close
#  iteration # 86 is done - 1641028611000, 15m, Any, Low
#  iteration # 87 is done - 1641028611000, 15m, Any, Close
#  iteration # 88 is done - 1641028611000, 15m, Any, Low
#  iteration # 89 is done - 1641028611000, 15m, Any, Close
#  iteration # 90 is done - 1641028611000, 15m, Any, Low
#  iteration # 91 is done - 1641028611000, 15m, Up, Close
#  iteration # 92 is done - 1641028611000, 15m, Up, Low
#  iteration # 93 is done - 1641028611000, 15m, Up, Close
#  iteration # 94 is done - 1641028611000, 15m, Up, Low
#  iteration # 95 is done - 1641028611000, 15m, Up, Close
#  iteration # 96 is done - 1641028611000, 15m, Up, Low
#  iteration # 97 is done - 1641028611000, 15m, Up, Close
#  iteration # 98 is done - 1641028611000, 15m, Up, Low
#  iteration # 99 is done - 1641028611000, 15m, Up, Close
#  iteration # 100 is done - 1641028611000, 15m, Up, Low
#  iteration # 101 is done - 1641028611000, 15m, Up, Close
#  iteration # 102 is done - 1641028611000, 15m, Up, Low
#  iteration # 103 is done - 1641028611000, 15m, Up, Close
#  iteration # 104 is done - 1641028611000, 15m, Up, Low
#  iteration # 105 is done - 1641028611000, 15m, Up, Close
#  iteration # 106 is done - 1641028611000, 15m, Up, Low
#  iteration # 107 is done - 1641028611000, 15m, Up, Close
#  iteration # 108 is done - 1641028611000, 15m, Up, Low
#  iteration # 109 is done - 1641028611000, 1h, Any, Close
#  iteration # 110 is done - 1641028611000, 1h, Any, Low
#  iteration # 111 is done - 1641028611000, 1h, Any, Close
#  iteration # 112 is done - 1641028611000, 1h, Any, Low
#  iteration # 113 is done - 1641028611000, 1h, Any, Close
#  iteration # 114 is done - 1641028611000, 1h, Any, Low
#  iteration # 115 is done - 1641028611000, 1h, Any, Close
#  iteration # 116 is done - 1641028611000, 1h, Any, Low
#  iteration # 117 is done - 1641028611000, 1h, Any, Close
#  iteration # 118 is done - 1641028611000, 1h, Any, Low
#  iteration # 119 is done - 1641028611000, 1h, Any, Close
#  iteration # 120 is done - 1641028611000, 1h, Any, Low
#  iteration # 121 is done - 1641028611000, 1h, Any, Close
#  iteration # 122 is done - 1641028611000, 1h, Any, Low
#  iteration # 123 is done - 1641028611000, 1h, Any, Close
#  iteration # 124 is done - 1641028611000, 1h, Any, Low
#  iteration # 125 is done - 1641028611000, 1h, Any, Close
#  iteration # 126 is done - 1641028611000, 1h, Any, Low
#  iteration # 127 is done - 1641028611000, 1h, Up, Close
#  iteration # 128 is done - 1641028611000, 1h, Up, Low
#  iteration # 129 is done - 1641028611000, 1h, Up, Close
#  iteration # 130 is done - 1641028611000, 1h, Up, Low
#  iteration # 131 is done - 1641028611000, 1h, Up, Close
#  iteration # 132 is done - 1641028611000, 1h, Up, Low
#  iteration # 133 is done - 1641028611000, 1h, Up, Close
#  iteration # 134 is done - 1641028611000, 1h, Up, Low
#  iteration # 135 is done - 1641028611000, 1h, Up, Close
#  iteration # 136 is done - 1641028611000, 1h, Up, Low
#  iteration # 137 is done - 1641028611000, 1h, Up, Close
#  iteration # 138 is done - 1641028611000, 1h, Up, Low
#  iteration # 139 is done - 1641028611000, 1h, Up, Close
#  iteration # 140 is done - 1641028611000, 1h, Up, Low
#  iteration # 141 is done - 1641028611000, 1h, Up, Close
#  iteration # 142 is done - 1641028611000, 1h, Up, Low
#  iteration # 143 is done - 1641028611000, 1h, Up, Close
#  iteration # 144 is done - 1641028611000, 1h, Up, Low
#  iteration # 145 is done - 1609459200000, 15m, Any, Close
#  iteration # 146 is done - 1609459200000, 15m, Any, Low
#  iteration # 147 is done - 1609459200000, 15m, Any, Close
#  iteration # 148 is done - 1609459200000, 15m, Any, Low
#  iteration # 149 is done - 1609459200000, 15m, Any, Close
#  iteration # 150 is done - 1609459200000, 15m, Any, Low
#  iteration # 151 is done - 1609459200000, 15m, Any, Close
#  iteration # 152 is done - 1609459200000, 15m, Any, Low
#  iteration # 153 is done - 1609459200000, 15m, Any, Close
#  iteration # 154 is done - 1609459200000, 15m, Any, Low
#  iteration # 155 is done - 1609459200000, 15m, Any, Close
#  iteration # 156 is done - 1609459200000, 15m, Any, Low
#  iteration # 157 is done - 1609459200000, 15m, Any, Close
#  iteration # 158 is done - 1609459200000, 15m, Any, Low
#  iteration # 159 is done - 1609459200000, 15m, Any, Close
#  iteration # 160 is done - 1609459200000, 15m, Any, Low
#  iteration # 161 is done - 1609459200000, 15m, Any, Close
#  iteration # 162 is done - 1609459200000, 15m, Any, Low
#  iteration # 163 is done - 1609459200000, 15m, Up, Close
#  iteration # 164 is done - 1609459200000, 15m, Up, Low
#  iteration # 165 is done - 1609459200000, 15m, Up, Close
#  iteration # 166 is done - 1609459200000, 15m, Up, Low
#  iteration # 167 is done - 1609459200000, 15m, Up, Close
#  iteration # 168 is done - 1609459200000, 15m, Up, Low
#  iteration # 169 is done - 1609459200000, 15m, Up, Close
#  iteration # 170 is done - 1609459200000, 15m, Up, Low
#  iteration # 171 is done - 1609459200000, 15m, Up, Close
#  iteration # 172 is done - 1609459200000, 15m, Up, Low
#  iteration # 173 is done - 1609459200000, 15m, Up, Close
#  iteration # 174 is done - 1609459200000, 15m, Up, Low
#  iteration # 175 is done - 1609459200000, 15m, Up, Close
#  iteration # 176 is done - 1609459200000, 15m, Up, Low
#  iteration # 177 is done - 1609459200000, 15m, Up, Close
#  iteration # 178 is done - 1609459200000, 15m, Up, Low
#  iteration # 179 is done - 1609459200000, 15m, Up, Close
#  iteration # 180 is done - 1609459200000, 15m, Up, Low
#  iteration # 181 is done - 1609459200000, 1h, Any, Close
#  iteration # 182 is done - 1609459200000, 1h, Any, Low
#  iteration # 183 is done - 1609459200000, 1h, Any, Close
#  iteration # 184 is done - 1609459200000, 1h, Any, Low
#  iteration # 185 is done - 1609459200000, 1h, Any, Close
#  iteration # 186 is done - 1609459200000, 1h, Any, Low
#  iteration # 187 is done - 1609459200000, 1h, Any, Close
#  iteration # 188 is done - 1609459200000, 1h, Any, Low
#  iteration # 189 is done - 1609459200000, 1h, Any, Close
#  iteration # 190 is done - 1609459200000, 1h, Any, Low
#  iteration # 191 is done - 1609459200000, 1h, Any, Close
#  iteration # 192 is done - 1609459200000, 1h, Any, Low
#  iteration # 193 is done - 1609459200000, 1h, Any, Close
#  iteration # 194 is done - 1609459200000, 1h, Any, Low
#  iteration # 195 is done - 1609459200000, 1h, Any, Close
#  iteration # 196 is done - 1609459200000, 1h, Any, Low
#  iteration # 197 is done - 1609459200000, 1h, Any, Close
#  iteration # 198 is done - 1609459200000, 1h, Any, Low
#  iteration # 199 is done - 1609459200000, 1h, Up, Close
#  iteration # 200 is done - 1609459200000, 1h, Up, Low
#  iteration # 201 is done - 1609459200000, 1h, Up, Close
#  iteration # 202 is done - 1609459200000, 1h, Up, Low
#  iteration # 203 is done - 1609459200000, 1h, Up, Close
#  iteration # 204 is done - 1609459200000, 1h, Up, Low
#  iteration # 205 is done - 1609459200000, 1h, Up, Close
#  iteration # 206 is done - 1609459200000, 1h, Up, Low
#  iteration # 207 is done - 1609459200000, 1h, Up, Close
#  iteration # 208 is done - 1609459200000, 1h, Up, Low
#  iteration # 209 is done - 1609459200000, 1h, Up, Close
#  iteration # 210 is done - 1609459200000, 1h, Up, Low
#  iteration # 211 is done - 1609459200000, 1h, Up, Close
#  iteration # 212 is done - 1609459200000, 1h, Up, Low
#  iteration # 213 is done - 1609459200000, 1h, Up, Close
#  iteration # 214 is done - 1609459200000, 1h, Up, Low
#  iteration # 215 is done - 1609459200000, 1h, Up, Close
#  iteration # 216 is done - 1609459200000, 1h, Up, Low
# Time taken to execute for loop: 5986.602056264877 seconds
#         start_time interval kd_dir  sl_atr  tp_atr sl_det    Profit       Fee  \
# 160  1609459200000      15m    Any       3      10  Close  60955.69  24055.26
# 158  1609459200000      15m    Any       3       8  Close  59192.31  24054.38
# 156  1609459200000      15m    Any       3       6  Close  54934.86  24061.27
# 196  1609459200000       1h    Any       3      10  Close  50742.92   6390.75
# 214  1609459200000       1h     Up       3      10  Close  49128.38   3392.52
# ..             ...      ...    ...     ...     ...    ...       ...       ...
# 147  1609459200000      15m    Any       1       8    Low -22463.53  24042.69
# 87   1641028611000      15m    Any       3       8    Low -22688.63  10298.85
# 155  1609459200000      15m    Any       2      10    Low -33353.02  24037.24
# 153  1609459200000      15m    Any       2       8    Low -33786.38  24037.02
# 151  1609459200000      15m    Any       2       6    Low -34222.12  24036.80
#
#      Max_Profit  Max_Loss  Max_Entry  Max_Position  Profit_%
# 160    19064.13  -1234.09         67     216619.51   281.40%
# 158    19064.13  -1234.09         67     216619.51   273.25%
# 156    19064.13  -1234.09         67     216619.51   253.60%
# 196    31092.91  -2367.13         77      99585.22   509.54%
# 214    43872.26  -1187.86         55     171514.87   286.44%
# ..          ...       ...        ...           ...       ...
# 147     1553.78   -270.25         26      50668.73  -443.34%
# 87      5494.48   -835.08         58      91913.84  -246.85%
# 155     5685.33   -591.57         41     149054.32  -223.76%
# 153     5685.33   -591.57         41     149054.32  -226.67%
# 151     5685.33   -591.57         41     149054.32  -229.59%
#
# [216 rows x 13 columns]

# %%
results_df.to_csv(f'results_df_007.csv')
