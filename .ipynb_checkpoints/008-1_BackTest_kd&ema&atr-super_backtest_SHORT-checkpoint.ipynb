# %%
# k crossover d，close > ema 8, ema 8 > ema 18, ema 18 > 38, take profit atr, stop loss atr
# Variables :
# time - 15m, 1h
# start time - 1609492611000, 1641028611000, 1672564611000 (2021, 2022, 2023)
# tp atr - 4, 6
# sl atr - 3, 5
# sl - Close, Low

# %%
# ! conda install -c conda-forge ta --yes

# %%
import requests
import pandas as pd
import ta
import datetime as dt
import numpy as np
import time
import itertools

# %%
start_time_arr = [1672531200000, 1641028611000, 1609492611000]
interval_arr = ['15m', '1h']
kd_dir_arr = ['Any', 'Up', 'Down']
sl_atr_arr = [2, 3, 4, 5]
tp_atr_arr = [3, 4, 5, 6]
sl_det_arr = ['Close', 'High']

# %%
timezone = 8
endpoint = 'wss://stream.binance.com:9443/ws'
symbol = 'ethusdt'
symbol_C = symbol.upper()

end_time = round(time.time() * 1000)

# step between timestamps in milliseconds
step = 60000 * 3600

# %%
def create_raw(symbol, interval_arr, start_time, end_time, step):
    
    url = "https://api.binance.com/api/v3/klines"
    
    for interval in interval_arr:

        raw_df = pd.DataFrame()
        
        for timestamp in range(start_time, end_time, step):
            params = {"symbol": symbol_C,
                      "interval": interval,
                      "startTime": timestamp,
                      "endTime": timestamp + step}
            response = requests.get(url, params=params).json()
            out = pd.DataFrame(response, columns = ["Open time", "Open", "High", "Low", "Close",
                                                   "Volume", "Close_Time", "Quote asset volume",
                                                   "Number of trades", "Taker buy base asset volume",
                                                   "Taker buy quote asset volume", "Ignore"])
            raw_df = pd.concat([raw_df, out], axis = 0)

        raw_df = raw_df[['Close_Time', 'Open', 'Close', "High", "Low", 'Volume']]

        raw_df.to_hdf(f'klines_{symbol}_{interval}.h5', key='df', mode='w')

# %%
loop_start_time = time.time()
create_raw(symbol, interval_arr, min(start_time_arr), end_time, step)
loop_end_time = time.time()
print("Time taken to execute for loop:", loop_end_time - loop_start_time, "seconds")
# Out:
# Time taken to execute for loop: 79.53179168701172 seconds

# %%
klines_cache = {}

def get_klines(symbol, interval, start_time, end_time, step):
    if (symbol, interval) not in klines_cache:
        klines_cache[(symbol, interval)] = pd.read_hdf(f'klines_{symbol}_{interval}.h5', key='df')

    df = klines_cache[(symbol, interval)].query(f"Close_Time >= {start_time} and Close_Time <= {end_time}")

    df = df[['Close_Time', 'Open', 'Close', "High", "Low", 'Volume']].astype(float)

    df['Close_Time'] = pd.to_datetime(df['Close_Time'], unit='ms') + pd.Timedelta(hours=timezone)
    df['Close_Time'] = df['Close_Time'].dt.strftime('%Y-%m-%d %H:%M:%S')
    
    df = df.reset_index(drop=True)

    return df

# %%
def check_cross(df, kd_dir):
    up = df['slow_k'] > df['slow_d']
    down = df['slow_k'] < df['slow_d']
    if kd_dir == 'Up':
        return up.diff() & up
    if kd_dir == 'Any':
        return up.diff()
    if kd_dir == 'Down':
        return down.diff() & down


def indicators(df, kd_dir):

# ema
    for i in (8, 18, 38):
        df['ema_'+str(i)] = ta.trend.ema_indicator(df.Close, window=i)

# atr
    df['atr'] = ta.volatility.average_true_range(df.High, df.Low, df.Close)
    
# rsi
    rsi_int = 14
    df['rsi'] = ta.momentum.RSIIndicator(df['Close'], window = rsi_int).rsi()

# kd
    kd_int = 14
    d_int = 3
   
    kd_df = pd.DataFrame()
    kd_df[str(kd_int) + '-Low'] = df['Low'].rolling(kd_int).min()
    kd_df[str(kd_int) + '-High'] = df['High'].rolling(kd_int).max()
    df['slow_k'] = (df['Close'] - kd_df[str(kd_int) + '-Low'])*100/(kd_df[str(kd_int) + '-High'] - kd_df[str(kd_int) + '-Low'])
    df['slow_d'] = df['slow_k'].rolling(d_int).mean()
    
# kd cross
    df['kd_cross'] = check_cross(df, kd_dir)
    
    return df

# %%
def conditions(df):

    for index, row in df.iterrows():
        # c1
        df['c1'] = df['kd_cross']
        # c2
        df['c2'] = df['Close'] <= df['ema_8']
        # c3
        df['c3'] = df['ema_8'] <= df['ema_18']
        # c4
        df['c4'] = df['ema_18'] <= df['ema_38']

    # 條件達成
    df['signal'] = False
    df.loc[df.c1 & df.c2 & df.c3 & df.c4 , 'signal'] = True


    # 下一根進場
    df['open_entry'] = False
    for i in range(len(df) - 1):
        if df.loc[i, 'signal'] == True:
            df.loc[i + 1, 'open_entry'] = True

# %%
def entries(df, sl_atr, tp_atr, sl_det):

    in_position = False
    stop_loss = np.nan
    take_profit = np.nan
    close_val = df['Close']
    atr_val = df['atr']

    for index, row in df.iterrows():

        if index == 0:
            continue

        elif df.at[index, 'open_entry'] == True:

            df.at[index, 'entry_p'] = close_val.shift(1).at[index]
            df.at[index, 'stop_loss'] = close_val.shift(1).at[index] + sl_atr * atr_val.shift(1).at[index]
            df.at[index, 'take_profit'] = close_val.shift(1).at[index] - tp_atr * atr_val.shift(1).at[index]
            df.at[index, 'position'] = 'Short'
            in_position = True
            stop_loss = df.at[index, 'stop_loss']
            take_profit = df.at[index, 'take_profit']


        # 吃筍
        #-----------------------------重要-----------------------------
        # 若用 if 寫，則有可能入場馬上吃筍，若用 elif 則一個 iteration 只會執行一次
        elif in_position == True and (df.at[index, sl_det] >= stop_loss):
            df.at[index, 'position'] = 'Stop'
            in_position = False
            stop_loss = np.nan
            take_profit = np.nan

        # set take profit
        elif in_position == True and (df.at[index, 'Low'] <= take_profit):
            df.at[index, 'position'] = 'Buy'
            in_position = False
            stop_loss = np.nan
            take_profit = np.nan
    

    # 過濾有訊號或事件發生的Ｋ線
    df = df[(df['open_entry'] == True) |
                  (df['signal'] == True) | 
                  (df['position'] == 'Short') |
                  (df['position'] == 'Buy') |
                  (df['position'] == 'Stop')]

# %%
# 部位回測
def backtest(df):

    df = df.reset_index(drop = True)
    df = df[(df['position'] == 'Short') |
                  (df['position'] == 'Buy') |
                  (df['position'] == 'Stop')]

    # 一次進場多少單位
    pos_size = 1

    col = ['Close_Time', 'Open', 'Close', 'High', 'Low', 'ema_8', 'ema_18', 'ema_38', 'atr', 'kd_cross', 'position','entry_p', 'stop_loss', 'take_profit']
    pos = df[col]
    pos = pos.reset_index(drop = True)


    for index, row in pos.iterrows():

        current_pos = 0

        # 進場
        if pos.at[index, 'position'] == 'Short':
            pos.at[index, 'size'] = pos_size
            pos.exit_p = np.nan

        # 出場
        if pos.at[index, 'position'] == 'Buy' or pos.at[index, 'position'] == 'Stop':

            # 停利：達成條件時收盤價
            if pos.at[index, 'position'] == 'Buy':
                for i in range(index -1, -1, -1):
                    if pos.at[i, 'position'] == 'Short':
                        pos.at[index, 'exit_p'] = pos.at[i, 'take_profit']
                    break

            # 停損：打到進場停損點（往回跌代，直到最近的'Buy'及其'stop_loss'）
            if pos.at[index, 'position'] == 'Stop':
                for i in range(index -1, -1, -1):
                    if pos.at[i, 'position'] == 'Short':
                        pos.at[index, 'exit_p'] = pos.at[i, 'stop_loss']
                    break

            # 計算每次出場部位大小（每次出場皆清倉）
            for i in range(index -1, -1, -1):
                if pos.at[i, 'position'] == 'Short':
                    current_pos += pos.at[i, 'size']
                    if i == 0:
                        pos.at[index, 'size'] = -current_pos
                    else:
                        continue
                else:
                    pos.at[index, 'size'] = -current_pos
                    current_pos = 0
                    break


    # 計算部位價值
    for index, row in pos.iterrows():
        if pos.at[index, 'position'] == 'Short':
            pos.at[index, 'amt'] = round(pos.at[index, 'size'] * pos.at[index, 'entry_p'], 4)
        elif pos.at[index, 'position'] == 'Buy' or pos.at[index, 'position'] == 'Stop':
            pos.at[index, 'amt'] = round(pos.at[index, 'size'] * pos.at[index, 'exit_p'], 4)


    # 若最後一筆為 Buy，移除該單，迭代驗證
    for index, row in pos.iloc[::-1].iterrows():
        if row['position'] == 'Short':
            pos = pos.drop(index)
        else:
            break


    # 手續費、滑點、價差
    fee = 0.05 / 100
    amt_abs_sum = pos.amt.abs().sum()
    ttl_fee = amt_abs_sum * fee

    # 損益
    leverage = 10
    ttl_profit = pos.amt.sum() - ttl_fee


    # 計算進場最大部位，最大損益
    consec_entry = 0
    position_amt_sum = 0
    max_consec_entry = 0
    max_position = 0
    max_profit = 0
    max_loss = 0

    for index, row in pos.iterrows():

        if row['position'] == 'Short':

            consec_entry += 1
            position_amt_sum += row['amt']

        elif row['position'] in ['Buy', 'Stop']:

            if consec_entry > max_consec_entry:
                max_consec_entry = consec_entry
                max_position = position_amt_sum

            position_amt_sum += row['amt']

            if position_amt_sum > max_profit:
                max_profit = position_amt_sum

            if position_amt_sum < max_loss:
                max_loss = position_amt_sum

            consec_entry = 0
            position_amt_sum = 0

        else:
            pass


    profit_per = "{:.2f}%".format(ttl_profit / (max_position/leverage) * 100)

    wins = pos['position'].str.count('Buy').sum()
    loses = pos['position'].str.count('Stop').sum()

    win_rate = "{:.2f}%".format(wins / (wins + loses) * 100)

    result = {'Profit': [round(ttl_profit, 2)],
              'Fee': [round(ttl_fee, 2)],
              'Max_Profit': [round(max_profit, 2)],
              'Max_Loss': [round(max_loss, 2)],
              'Max_Entry': [max_consec_entry],
              'Max_Position': [round(max_position, 2)],
              'Profit_%': [profit_per],
              'Win_Rate': [win_rate]}


    result_df = pd.DataFrame(result)
    
    return result_df

# %%
def run_backtest():

    results_df = pd.DataFrame()

    start_time_list = []
    interval_list = []
    kd_dir_list = []
    sl_atr_list = []
    tp_atr_list = []
    sl_det_list = []

    i = 0

    loop_start_time = time.time()

    for start_time, interval, kd_dir, sl_atr, tp_atr, sl_det in itertools.product(start_time_arr,
                                                                                              interval_arr,
                                                                                              kd_dir_arr,
                                                                                              sl_atr_arr,
                                                                                              tp_atr_arr,
                                                                                              sl_det_arr):

        df = get_klines(symbol, interval, start_time, end_time, step)

        indicators(df, kd_dir)
        conditions(df)
        entries(df, sl_atr, tp_atr, sl_det)
        results_df = pd.concat([results_df, backtest(df)], ignore_index = True)

        start_time_list.append(start_time)
        interval_list.append(interval)
        kd_dir_list.append(kd_dir)
        sl_atr_list.append(sl_atr)
        tp_atr_list.append(tp_atr)
        sl_det_list.append(sl_det)

        i += 1

        print(f" iteration # {i} is done - {start_time}, {interval}, {kd_dir}, {sl_det}")

    loop_end_time = time.time()

    print("Time taken to execute for loop:", loop_end_time - loop_start_time, "seconds")

    results_df['start_time'] = start_time_list
    results_df['interval'] = interval_list
    results_df['kd_dir'] = kd_dir_list
    results_df['sl_atr'] = sl_atr_list
    results_df['tp_atr'] = tp_atr_list
    results_df['sl_det'] = sl_det_list

    results_df = results_df[['start_time', 'interval', 'kd_dir',
                             'sl_atr', 'tp_atr', 'sl_det',
                             'Profit', 'Fee', 'Max_Profit', 'Max_Loss',
                             'Max_Entry', 'Max_Position', 'Profit_%'
                            ]]
    
    return results_df

# %%
results_df = run_backtest()
results_df = results_df.sort_values('Profit', ascending = False)
print(results_df)
# Out:
#  iteration # 1 is done - 1672531200000, 15m, Any, Close
#  iteration # 2 is done - 1672531200000, 15m, Any, High
#  iteration # 3 is done - 1672531200000, 15m, Any, Close
#  iteration # 4 is done - 1672531200000, 15m, Any, High
#  iteration # 5 is done - 1672531200000, 15m, Any, Close
#  iteration # 6 is done - 1672531200000, 15m, Any, High
#  iteration # 7 is done - 1672531200000, 15m, Any, Close
#  iteration # 8 is done - 1672531200000, 15m, Any, High
#  iteration # 9 is done - 1672531200000, 15m, Any, Close
#  iteration # 10 is done - 1672531200000, 15m, Any, High
#  iteration # 11 is done - 1672531200000, 15m, Any, Close
#  iteration # 12 is done - 1672531200000, 15m, Any, High
#  iteration # 13 is done - 1672531200000, 15m, Any, Close
#  iteration # 14 is done - 1672531200000, 15m, Any, High
#  iteration # 15 is done - 1672531200000, 15m, Any, Close
#  iteration # 16 is done - 1672531200000, 15m, Any, High
#  iteration # 17 is done - 1672531200000, 15m, Any, Close
#  iteration # 18 is done - 1672531200000, 15m, Any, High
#  iteration # 19 is done - 1672531200000, 15m, Any, Close
#  iteration # 20 is done - 1672531200000, 15m, Any, High
#  iteration # 21 is done - 1672531200000, 15m, Any, Close
#  iteration # 22 is done - 1672531200000, 15m, Any, High
#  iteration # 23 is done - 1672531200000, 15m, Any, Close
#  iteration # 24 is done - 1672531200000, 15m, Any, High
#  iteration # 25 is done - 1672531200000, 15m, Any, Close
#  iteration # 26 is done - 1672531200000, 15m, Any, High
#  iteration # 27 is done - 1672531200000, 15m, Any, Close
#  iteration # 28 is done - 1672531200000, 15m, Any, High
#  iteration # 29 is done - 1672531200000, 15m, Any, Close
#  iteration # 30 is done - 1672531200000, 15m, Any, High
#  iteration # 31 is done - 1672531200000, 15m, Any, Close
#  iteration # 32 is done - 1672531200000, 15m, Any, High
#  iteration # 33 is done - 1672531200000, 15m, Up, Close
#  iteration # 34 is done - 1672531200000, 15m, Up, High
#  iteration # 35 is done - 1672531200000, 15m, Up, Close
#  iteration # 36 is done - 1672531200000, 15m, Up, High
#  iteration # 37 is done - 1672531200000, 15m, Up, Close
#  iteration # 38 is done - 1672531200000, 15m, Up, High
#  iteration # 39 is done - 1672531200000, 15m, Up, Close
#  iteration # 40 is done - 1672531200000, 15m, Up, High
#  iteration # 41 is done - 1672531200000, 15m, Up, Close
#  iteration # 42 is done - 1672531200000, 15m, Up, High
#  iteration # 43 is done - 1672531200000, 15m, Up, Close
#  iteration # 44 is done - 1672531200000, 15m, Up, High
#  iteration # 45 is done - 1672531200000, 15m, Up, Close
#  iteration # 46 is done - 1672531200000, 15m, Up, High
#  iteration # 47 is done - 1672531200000, 15m, Up, Close
#  iteration # 48 is done - 1672531200000, 15m, Up, High
#  iteration # 49 is done - 1672531200000, 15m, Up, Close
#  iteration # 50 is done - 1672531200000, 15m, Up, High
#  iteration # 51 is done - 1672531200000, 15m, Up, Close
#  iteration # 52 is done - 1672531200000, 15m, Up, High
#  iteration # 53 is done - 1672531200000, 15m, Up, Close
#  iteration # 54 is done - 1672531200000, 15m, Up, High
#  iteration # 55 is done - 1672531200000, 15m, Up, Close
#  iteration # 56 is done - 1672531200000, 15m, Up, High
#  iteration # 57 is done - 1672531200000, 15m, Up, Close
#  iteration # 58 is done - 1672531200000, 15m, Up, High
#  iteration # 59 is done - 1672531200000, 15m, Up, Close
#  iteration # 60 is done - 1672531200000, 15m, Up, High
#  iteration # 61 is done - 1672531200000, 15m, Up, Close
#  iteration # 62 is done - 1672531200000, 15m, Up, High
#  iteration # 63 is done - 1672531200000, 15m, Up, Close
#  iteration # 64 is done - 1672531200000, 15m, Up, High
#  iteration # 65 is done - 1672531200000, 15m, Down, Close
#  iteration # 66 is done - 1672531200000, 15m, Down, High
#  iteration # 67 is done - 1672531200000, 15m, Down, Close
#  iteration # 68 is done - 1672531200000, 15m, Down, High
#  iteration # 69 is done - 1672531200000, 15m, Down, Close
#  iteration # 70 is done - 1672531200000, 15m, Down, High
#  iteration # 71 is done - 1672531200000, 15m, Down, Close
#  iteration # 72 is done - 1672531200000, 15m, Down, High
#  iteration # 73 is done - 1672531200000, 15m, Down, Close
#  iteration # 74 is done - 1672531200000, 15m, Down, High
#  iteration # 75 is done - 1672531200000, 15m, Down, Close
#  iteration # 76 is done - 1672531200000, 15m, Down, High
#  iteration # 77 is done - 1672531200000, 15m, Down, Close
#  iteration # 78 is done - 1672531200000, 15m, Down, High
#  iteration # 79 is done - 1672531200000, 15m, Down, Close
#  iteration # 80 is done - 1672531200000, 15m, Down, High
#  iteration # 81 is done - 1672531200000, 15m, Down, Close
#  iteration # 82 is done - 1672531200000, 15m, Down, High
#  iteration # 83 is done - 1672531200000, 15m, Down, Close
#  iteration # 84 is done - 1672531200000, 15m, Down, High
#  iteration # 85 is done - 1672531200000, 15m, Down, Close
#  iteration # 86 is done - 1672531200000, 15m, Down, High
#  iteration # 87 is done - 1672531200000, 15m, Down, Close
#  iteration # 88 is done - 1672531200000, 15m, Down, High
#  iteration # 89 is done - 1672531200000, 15m, Down, Close
#  iteration # 90 is done - 1672531200000, 15m, Down, High
#  iteration # 91 is done - 1672531200000, 15m, Down, Close
#  iteration # 92 is done - 1672531200000, 15m, Down, High
#  iteration # 93 is done - 1672531200000, 15m, Down, Close
#  iteration # 94 is done - 1672531200000, 15m, Down, High
#  iteration # 95 is done - 1672531200000, 15m, Down, Close
#  iteration # 96 is done - 1672531200000, 15m, Down, High
#  iteration # 97 is done - 1672531200000, 1h, Any, Close
#  iteration # 98 is done - 1672531200000, 1h, Any, High
#  iteration # 99 is done - 1672531200000, 1h, Any, Close
#  iteration # 100 is done - 1672531200000, 1h, Any, High
#  iteration # 101 is done - 1672531200000, 1h, Any, Close
#  iteration # 102 is done - 1672531200000, 1h, Any, High
#  iteration # 103 is done - 1672531200000, 1h, Any, Close
#  iteration # 104 is done - 1672531200000, 1h, Any, High
#  iteration # 105 is done - 1672531200000, 1h, Any, Close
#  iteration # 106 is done - 1672531200000, 1h, Any, High
#  iteration # 107 is done - 1672531200000, 1h, Any, Close
#  iteration # 108 is done - 1672531200000, 1h, Any, High
#  iteration # 109 is done - 1672531200000, 1h, Any, Close
#  iteration # 110 is done - 1672531200000, 1h, Any, High
#  iteration # 111 is done - 1672531200000, 1h, Any, Close
#  iteration # 112 is done - 1672531200000, 1h, Any, High
#  iteration # 113 is done - 1672531200000, 1h, Any, Close
#  iteration # 114 is done - 1672531200000, 1h, Any, High
#  iteration # 115 is done - 1672531200000, 1h, Any, Close
#  iteration # 116 is done - 1672531200000, 1h, Any, High
#  iteration # 117 is done - 1672531200000, 1h, Any, Close
#  iteration # 118 is done - 1672531200000, 1h, Any, High
#  iteration # 119 is done - 1672531200000, 1h, Any, Close
#  iteration # 120 is done - 1672531200000, 1h, Any, High
#  iteration # 121 is done - 1672531200000, 1h, Any, Close
#  iteration # 122 is done - 1672531200000, 1h, Any, High
#  iteration # 123 is done - 1672531200000, 1h, Any, Close
#  iteration # 124 is done - 1672531200000, 1h, Any, High
#  iteration # 125 is done - 1672531200000, 1h, Any, Close
#  iteration # 126 is done - 1672531200000, 1h, Any, High
#  iteration # 127 is done - 1672531200000, 1h, Any, Close
#  iteration # 128 is done - 1672531200000, 1h, Any, High
#  iteration # 129 is done - 1672531200000, 1h, Up, Close
#  iteration # 130 is done - 1672531200000, 1h, Up, High
#  iteration # 131 is done - 1672531200000, 1h, Up, Close
#  iteration # 132 is done - 1672531200000, 1h, Up, High
#  iteration # 133 is done - 1672531200000, 1h, Up, Close
#  iteration # 134 is done - 1672531200000, 1h, Up, High
#  iteration # 135 is done - 1672531200000, 1h, Up, Close
#  iteration # 136 is done - 1672531200000, 1h, Up, High
#  iteration # 137 is done - 1672531200000, 1h, Up, Close
#  iteration # 138 is done - 1672531200000, 1h, Up, High
#  iteration # 139 is done - 1672531200000, 1h, Up, Close
#  iteration # 140 is done - 1672531200000, 1h, Up, High
#  iteration # 141 is done - 1672531200000, 1h, Up, Close
#  iteration # 142 is done - 1672531200000, 1h, Up, High
#  iteration # 143 is done - 1672531200000, 1h, Up, Close
#  iteration # 144 is done - 1672531200000, 1h, Up, High
#  iteration # 145 is done - 1672531200000, 1h, Up, Close
#  iteration # 146 is done - 1672531200000, 1h, Up, High
#  iteration # 147 is done - 1672531200000, 1h, Up, Close
#  iteration # 148 is done - 1672531200000, 1h, Up, High
#  iteration # 149 is done - 1672531200000, 1h, Up, Close
#  iteration # 150 is done - 1672531200000, 1h, Up, High
#  iteration # 151 is done - 1672531200000, 1h, Up, Close
#  iteration # 152 is done - 1672531200000, 1h, Up, High
#  iteration # 153 is done - 1672531200000, 1h, Up, Close
#  iteration # 154 is done - 1672531200000, 1h, Up, High
#  iteration # 155 is done - 1672531200000, 1h, Up, Close
#  iteration # 156 is done - 1672531200000, 1h, Up, High
#  iteration # 157 is done - 1672531200000, 1h, Up, Close
#  iteration # 158 is done - 1672531200000, 1h, Up, High
#  iteration # 159 is done - 1672531200000, 1h, Up, Close
#  iteration # 160 is done - 1672531200000, 1h, Up, High
#  iteration # 161 is done - 1672531200000, 1h, Down, Close
#  iteration # 162 is done - 1672531200000, 1h, Down, High
#  iteration # 163 is done - 1672531200000, 1h, Down, Close
#  iteration # 164 is done - 1672531200000, 1h, Down, High
#  iteration # 165 is done - 1672531200000, 1h, Down, Close
#  iteration # 166 is done - 1672531200000, 1h, Down, High
#  iteration # 167 is done - 1672531200000, 1h, Down, Close
#  iteration # 168 is done - 1672531200000, 1h, Down, High
#  iteration # 169 is done - 1672531200000, 1h, Down, Close
#  iteration # 170 is done - 1672531200000, 1h, Down, High
#  iteration # 171 is done - 1672531200000, 1h, Down, Close
#  iteration # 172 is done - 1672531200000, 1h, Down, High
#  iteration # 173 is done - 1672531200000, 1h, Down, Close
#  iteration # 174 is done - 1672531200000, 1h, Down, High
#  iteration # 175 is done - 1672531200000, 1h, Down, Close
#  iteration # 176 is done - 1672531200000, 1h, Down, High
#  iteration # 177 is done - 1672531200000, 1h, Down, Close
#  iteration # 178 is done - 1672531200000, 1h, Down, High
#  iteration # 179 is done - 1672531200000, 1h, Down, Close
#  iteration # 180 is done - 1672531200000, 1h, Down, High
#  iteration # 181 is done - 1672531200000, 1h, Down, Close
#  iteration # 182 is done - 1672531200000, 1h, Down, High
#  iteration # 183 is done - 1672531200000, 1h, Down, Close
#  iteration # 184 is done - 1672531200000, 1h, Down, High
#  iteration # 185 is done - 1672531200000, 1h, Down, Close
#  iteration # 186 is done - 1672531200000, 1h, Down, High
#  iteration # 187 is done - 1672531200000, 1h, Down, Close
#  iteration # 188 is done - 1672531200000, 1h, Down, High
#  iteration # 189 is done - 1672531200000, 1h, Down, Close
#  iteration # 190 is done - 1672531200000, 1h, Down, High
#  iteration # 191 is done - 1672531200000, 1h, Down, Close
#  iteration # 192 is done - 1672531200000, 1h, Down, High
#  iteration # 193 is done - 1641028611000, 15m, Any, Close
#  iteration # 194 is done - 1641028611000, 15m, Any, High
#  iteration # 195 is done - 1641028611000, 15m, Any, Close
#  iteration # 196 is done - 1641028611000, 15m, Any, High
#  iteration # 197 is done - 1641028611000, 15m, Any, Close
#  iteration # 198 is done - 1641028611000, 15m, Any, High
#  iteration # 199 is done - 1641028611000, 15m, Any, Close
#  iteration # 200 is done - 1641028611000, 15m, Any, High
#  iteration # 201 is done - 1641028611000, 15m, Any, Close
#  iteration # 202 is done - 1641028611000, 15m, Any, High
#  iteration # 203 is done - 1641028611000, 15m, Any, Close
#  iteration # 204 is done - 1641028611000, 15m, Any, High
#  iteration # 205 is done - 1641028611000, 15m, Any, Close
#  iteration # 206 is done - 1641028611000, 15m, Any, High
#  iteration # 207 is done - 1641028611000, 15m, Any, Close
#  iteration # 208 is done - 1641028611000, 15m, Any, High
#  iteration # 209 is done - 1641028611000, 15m, Any, Close
#  iteration # 210 is done - 1641028611000, 15m, Any, High
#  iteration # 211 is done - 1641028611000, 15m, Any, Close
#  iteration # 212 is done - 1641028611000, 15m, Any, High
#  iteration # 213 is done - 1641028611000, 15m, Any, Close
#  iteration # 214 is done - 1641028611000, 15m, Any, High
#  iteration # 215 is done - 1641028611000, 15m, Any, Close
#  iteration # 216 is done - 1641028611000, 15m, Any, High
#  iteration # 217 is done - 1641028611000, 15m, Any, Close
#  iteration # 218 is done - 1641028611000, 15m, Any, High
#  iteration # 219 is done - 1641028611000, 15m, Any, Close
#  iteration # 220 is done - 1641028611000, 15m, Any, High
#  iteration # 221 is done - 1641028611000, 15m, Any, Close
#  iteration # 222 is done - 1641028611000, 15m, Any, High
#  iteration # 223 is done - 1641028611000, 15m, Any, Close
#  iteration # 224 is done - 1641028611000, 15m, Any, High
#  iteration # 225 is done - 1641028611000, 15m, Up, Close
#  iteration # 226 is done - 1641028611000, 15m, Up, High
#  iteration # 227 is done - 1641028611000, 15m, Up, Close
#  iteration # 228 is done - 1641028611000, 15m, Up, High
#  iteration # 229 is done - 1641028611000, 15m, Up, Close
#  iteration # 230 is done - 1641028611000, 15m, Up, High
#  iteration # 231 is done - 1641028611000, 15m, Up, Close
#  iteration # 232 is done - 1641028611000, 15m, Up, High
#  iteration # 233 is done - 1641028611000, 15m, Up, Close
#  iteration # 234 is done - 1641028611000, 15m, Up, High
#  iteration # 235 is done - 1641028611000, 15m, Up, Close
#  iteration # 236 is done - 1641028611000, 15m, Up, High
#  iteration # 237 is done - 1641028611000, 15m, Up, Close
#  iteration # 238 is done - 1641028611000, 15m, Up, High
#  iteration # 239 is done - 1641028611000, 15m, Up, Close
#  iteration # 240 is done - 1641028611000, 15m, Up, High
#  iteration # 241 is done - 1641028611000, 15m, Up, Close
#  iteration # 242 is done - 1641028611000, 15m, Up, High
#  iteration # 243 is done - 1641028611000, 15m, Up, Close
#  iteration # 244 is done - 1641028611000, 15m, Up, High
#  iteration # 245 is done - 1641028611000, 15m, Up, Close
#  iteration # 246 is done - 1641028611000, 15m, Up, High
#  iteration # 247 is done - 1641028611000, 15m, Up, Close
#  iteration # 248 is done - 1641028611000, 15m, Up, High
#  iteration # 249 is done - 1641028611000, 15m, Up, Close
#  iteration # 250 is done - 1641028611000, 15m, Up, High
#  iteration # 251 is done - 1641028611000, 15m, Up, Close
#  iteration # 252 is done - 1641028611000, 15m, Up, High
#  iteration # 253 is done - 1641028611000, 15m, Up, Close
#  iteration # 254 is done - 1641028611000, 15m, Up, High
#  iteration # 255 is done - 1641028611000, 15m, Up, Close
#  iteration # 256 is done - 1641028611000, 15m, Up, High
#  iteration # 257 is done - 1641028611000, 15m, Down, Close
#  iteration # 258 is done - 1641028611000, 15m, Down, High
#  iteration # 259 is done - 1641028611000, 15m, Down, Close
#  iteration # 260 is done - 1641028611000, 15m, Down, High
#  iteration # 261 is done - 1641028611000, 15m, Down, Close
#  iteration # 262 is done - 1641028611000, 15m, Down, High
#  iteration # 263 is done - 1641028611000, 15m, Down, Close
#  iteration # 264 is done - 1641028611000, 15m, Down, High
#  iteration # 265 is done - 1641028611000, 15m, Down, Close
#  iteration # 266 is done - 1641028611000, 15m, Down, High
#  iteration # 267 is done - 1641028611000, 15m, Down, Close
#  iteration # 268 is done - 1641028611000, 15m, Down, High
#  iteration # 269 is done - 1641028611000, 15m, Down, Close
#  iteration # 270 is done - 1641028611000, 15m, Down, High
#  iteration # 271 is done - 1641028611000, 15m, Down, Close
#  iteration # 272 is done - 1641028611000, 15m, Down, High
#  iteration # 273 is done - 1641028611000, 15m, Down, Close
#  iteration # 274 is done - 1641028611000, 15m, Down, High
#  iteration # 275 is done - 1641028611000, 15m, Down, Close
#  iteration # 276 is done - 1641028611000, 15m, Down, High
#  iteration # 277 is done - 1641028611000, 15m, Down, Close
#  iteration # 278 is done - 1641028611000, 15m, Down, High
#  iteration # 279 is done - 1641028611000, 15m, Down, Close
#  iteration # 280 is done - 1641028611000, 15m, Down, High
#  iteration # 281 is done - 1641028611000, 15m, Down, Close
#  iteration # 282 is done - 1641028611000, 15m, Down, High
#  iteration # 283 is done - 1641028611000, 15m, Down, Close
#  iteration # 284 is done - 1641028611000, 15m, Down, High
#  iteration # 285 is done - 1641028611000, 15m, Down, Close
#  iteration # 286 is done - 1641028611000, 15m, Down, High
#  iteration # 287 is done - 1641028611000, 15m, Down, Close
#  iteration # 288 is done - 1641028611000, 15m, Down, High
#  iteration # 289 is done - 1641028611000, 1h, Any, Close
#  iteration # 290 is done - 1641028611000, 1h, Any, High
#  iteration # 291 is done - 1641028611000, 1h, Any, Close
#  iteration # 292 is done - 1641028611000, 1h, Any, High
#  iteration # 293 is done - 1641028611000, 1h, Any, Close
#  iteration # 294 is done - 1641028611000, 1h, Any, High
#  iteration # 295 is done - 1641028611000, 1h, Any, Close
#  iteration # 296 is done - 1641028611000, 1h, Any, High
#  iteration # 297 is done - 1641028611000, 1h, Any, Close
#  iteration # 298 is done - 1641028611000, 1h, Any, High
#  iteration # 299 is done - 1641028611000, 1h, Any, Close
#  iteration # 300 is done - 1641028611000, 1h, Any, High
#  iteration # 301 is done - 1641028611000, 1h, Any, Close
#  iteration # 302 is done - 1641028611000, 1h, Any, High
#  iteration # 303 is done - 1641028611000, 1h, Any, Close
#  iteration # 304 is done - 1641028611000, 1h, Any, High
#  iteration # 305 is done - 1641028611000, 1h, Any, Close
#  iteration # 306 is done - 1641028611000, 1h, Any, High
#  iteration # 307 is done - 1641028611000, 1h, Any, Close
#  iteration # 308 is done - 1641028611000, 1h, Any, High
#  iteration # 309 is done - 1641028611000, 1h, Any, Close
#  iteration # 310 is done - 1641028611000, 1h, Any, High
#  iteration # 311 is done - 1641028611000, 1h, Any, Close
#  iteration # 312 is done - 1641028611000, 1h, Any, High
#  iteration # 313 is done - 1641028611000, 1h, Any, Close
#  iteration # 314 is done - 1641028611000, 1h, Any, High
#  iteration # 315 is done - 1641028611000, 1h, Any, Close
#  iteration # 316 is done - 1641028611000, 1h, Any, High
#  iteration # 317 is done - 1641028611000, 1h, Any, Close
#  iteration # 318 is done - 1641028611000, 1h, Any, High
#  iteration # 319 is done - 1641028611000, 1h, Any, Close
#  iteration # 320 is done - 1641028611000, 1h, Any, High
#  iteration # 321 is done - 1641028611000, 1h, Up, Close
#  iteration # 322 is done - 1641028611000, 1h, Up, High
#  iteration # 323 is done - 1641028611000, 1h, Up, Close
#  iteration # 324 is done - 1641028611000, 1h, Up, High
#  iteration # 325 is done - 1641028611000, 1h, Up, Close
#  iteration # 326 is done - 1641028611000, 1h, Up, High
#  iteration # 327 is done - 1641028611000, 1h, Up, Close
#  iteration # 328 is done - 1641028611000, 1h, Up, High
#  iteration # 329 is done - 1641028611000, 1h, Up, Close
#  iteration # 330 is done - 1641028611000, 1h, Up, High
#  iteration # 331 is done - 1641028611000, 1h, Up, Close
#  iteration # 332 is done - 1641028611000, 1h, Up, High
#  iteration # 333 is done - 1641028611000, 1h, Up, Close
#  iteration # 334 is done - 1641028611000, 1h, Up, High
#  iteration # 335 is done - 1641028611000, 1h, Up, Close
#  iteration # 336 is done - 1641028611000, 1h, Up, High
#  iteration # 337 is done - 1641028611000, 1h, Up, Close
#  iteration # 338 is done - 1641028611000, 1h, Up, High
#  iteration # 339 is done - 1641028611000, 1h, Up, Close
#  iteration # 340 is done - 1641028611000, 1h, Up, High
#  iteration # 341 is done - 1641028611000, 1h, Up, Close
#  iteration # 342 is done - 1641028611000, 1h, Up, High
#  iteration # 343 is done - 1641028611000, 1h, Up, Close
#  iteration # 344 is done - 1641028611000, 1h, Up, High
#  iteration # 345 is done - 1641028611000, 1h, Up, Close
#  iteration # 346 is done - 1641028611000, 1h, Up, High
#  iteration # 347 is done - 1641028611000, 1h, Up, Close
#  iteration # 348 is done - 1641028611000, 1h, Up, High
#  iteration # 349 is done - 1641028611000, 1h, Up, Close
#  iteration # 350 is done - 1641028611000, 1h, Up, High
#  iteration # 351 is done - 1641028611000, 1h, Up, Close
#  iteration # 352 is done - 1641028611000, 1h, Up, High
#  iteration # 353 is done - 1641028611000, 1h, Down, Close
#  iteration # 354 is done - 1641028611000, 1h, Down, High
#  iteration # 355 is done - 1641028611000, 1h, Down, Close
#  iteration # 356 is done - 1641028611000, 1h, Down, High
#  iteration # 357 is done - 1641028611000, 1h, Down, Close
#  iteration # 358 is done - 1641028611000, 1h, Down, High
#  iteration # 359 is done - 1641028611000, 1h, Down, Close
#  iteration # 360 is done - 1641028611000, 1h, Down, High
#  iteration # 361 is done - 1641028611000, 1h, Down, Close
#  iteration # 362 is done - 1641028611000, 1h, Down, High
#  iteration # 363 is done - 1641028611000, 1h, Down, Close
#  iteration # 364 is done - 1641028611000, 1h, Down, High
#  iteration # 365 is done - 1641028611000, 1h, Down, Close
#  iteration # 366 is done - 1641028611000, 1h, Down, High
#  iteration # 367 is done - 1641028611000, 1h, Down, Close
#  iteration # 368 is done - 1641028611000, 1h, Down, High
#  iteration # 369 is done - 1641028611000, 1h, Down, Close
#  iteration # 370 is done - 1641028611000, 1h, Down, High
#  iteration # 371 is done - 1641028611000, 1h, Down, Close
#  iteration # 372 is done - 1641028611000, 1h, Down, High
#  iteration # 373 is done - 1641028611000, 1h, Down, Close
#  iteration # 374 is done - 1641028611000, 1h, Down, High
#  iteration # 375 is done - 1641028611000, 1h, Down, Close
#  iteration # 376 is done - 1641028611000, 1h, Down, High
#  iteration # 377 is done - 1641028611000, 1h, Down, Close
#  iteration # 378 is done - 1641028611000, 1h, Down, High
#  iteration # 379 is done - 1641028611000, 1h, Down, Close
#  iteration # 380 is done - 1641028611000, 1h, Down, High
#  iteration # 381 is done - 1641028611000, 1h, Down, Close
#  iteration # 382 is done - 1641028611000, 1h, Down, High
#  iteration # 383 is done - 1641028611000, 1h, Down, Close
#  iteration # 384 is done - 1641028611000, 1h, Down, High
#  iteration # 385 is done - 1609492611000, 15m, Any, Close
#  iteration # 386 is done - 1609492611000, 15m, Any, High
#  iteration # 387 is done - 1609492611000, 15m, Any, Close
#  iteration # 388 is done - 1609492611000, 15m, Any, High
#  iteration # 389 is done - 1609492611000, 15m, Any, Close
#  iteration # 390 is done - 1609492611000, 15m, Any, High
#  iteration # 391 is done - 1609492611000, 15m, Any, Close
#  iteration # 392 is done - 1609492611000, 15m, Any, High
#  iteration # 393 is done - 1609492611000, 15m, Any, Close
#  iteration # 394 is done - 1609492611000, 15m, Any, High
#  iteration # 395 is done - 1609492611000, 15m, Any, Close
#  iteration # 396 is done - 1609492611000, 15m, Any, High
#  iteration # 397 is done - 1609492611000, 15m, Any, Close
#  iteration # 398 is done - 1609492611000, 15m, Any, High
#  iteration # 399 is done - 1609492611000, 15m, Any, Close
#  iteration # 400 is done - 1609492611000, 15m, Any, High
#  iteration # 401 is done - 1609492611000, 15m, Any, Close
#  iteration # 402 is done - 1609492611000, 15m, Any, High
#  iteration # 403 is done - 1609492611000, 15m, Any, Close
#  iteration # 404 is done - 1609492611000, 15m, Any, High
#  iteration # 405 is done - 1609492611000, 15m, Any, Close
#  iteration # 406 is done - 1609492611000, 15m, Any, High
#  iteration # 407 is done - 1609492611000, 15m, Any, Close
#  iteration # 408 is done - 1609492611000, 15m, Any, High
#  iteration # 409 is done - 1609492611000, 15m, Any, Close
#  iteration # 410 is done - 1609492611000, 15m, Any, High
#  iteration # 411 is done - 1609492611000, 15m, Any, Close
#  iteration # 412 is done - 1609492611000, 15m, Any, High
#  iteration # 413 is done - 1609492611000, 15m, Any, Close
#  iteration # 414 is done - 1609492611000, 15m, Any, High
#  iteration # 415 is done - 1609492611000, 15m, Any, Close
#  iteration # 416 is done - 1609492611000, 15m, Any, High
#  iteration # 417 is done - 1609492611000, 15m, Up, Close
#  iteration # 418 is done - 1609492611000, 15m, Up, High
#  iteration # 419 is done - 1609492611000, 15m, Up, Close
#  iteration # 420 is done - 1609492611000, 15m, Up, High
#  iteration # 421 is done - 1609492611000, 15m, Up, Close
#  iteration # 422 is done - 1609492611000, 15m, Up, High
#  iteration # 423 is done - 1609492611000, 15m, Up, Close
#  iteration # 424 is done - 1609492611000, 15m, Up, High
#  iteration # 425 is done - 1609492611000, 15m, Up, Close
#  iteration # 426 is done - 1609492611000, 15m, Up, High
#  iteration # 427 is done - 1609492611000, 15m, Up, Close
#  iteration # 428 is done - 1609492611000, 15m, Up, High
#  iteration # 429 is done - 1609492611000, 15m, Up, Close
#  iteration # 430 is done - 1609492611000, 15m, Up, High
#  iteration # 431 is done - 1609492611000, 15m, Up, Close
#  iteration # 432 is done - 1609492611000, 15m, Up, High
#  iteration # 433 is done - 1609492611000, 15m, Up, Close
#  iteration # 434 is done - 1609492611000, 15m, Up, High
#  iteration # 435 is done - 1609492611000, 15m, Up, Close
#  iteration # 436 is done - 1609492611000, 15m, Up, High
#  iteration # 437 is done - 1609492611000, 15m, Up, Close
#  iteration # 438 is done - 1609492611000, 15m, Up, High
#  iteration # 439 is done - 1609492611000, 15m, Up, Close
#  iteration # 440 is done - 1609492611000, 15m, Up, High
#  iteration # 441 is done - 1609492611000, 15m, Up, Close
#  iteration # 442 is done - 1609492611000, 15m, Up, High
#  iteration # 443 is done - 1609492611000, 15m, Up, Close
#  iteration # 444 is done - 1609492611000, 15m, Up, High
#  iteration # 445 is done - 1609492611000, 15m, Up, Close
#  iteration # 446 is done - 1609492611000, 15m, Up, High
#  iteration # 447 is done - 1609492611000, 15m, Up, Close
#  iteration # 448 is done - 1609492611000, 15m, Up, High
#  iteration # 449 is done - 1609492611000, 15m, Down, Close
#  iteration # 450 is done - 1609492611000, 15m, Down, High
#  iteration # 451 is done - 1609492611000, 15m, Down, Close
#  iteration # 452 is done - 1609492611000, 15m, Down, High
#  iteration # 453 is done - 1609492611000, 15m, Down, Close
#  iteration # 454 is done - 1609492611000, 15m, Down, High
#  iteration # 455 is done - 1609492611000, 15m, Down, Close
#  iteration # 456 is done - 1609492611000, 15m, Down, High
#  iteration # 457 is done - 1609492611000, 15m, Down, Close
#  iteration # 458 is done - 1609492611000, 15m, Down, High
#  iteration # 459 is done - 1609492611000, 15m, Down, Close
#  iteration # 460 is done - 1609492611000, 15m, Down, High
#  iteration # 461 is done - 1609492611000, 15m, Down, Close
#  iteration # 462 is done - 1609492611000, 15m, Down, High
#  iteration # 463 is done - 1609492611000, 15m, Down, Close
#  iteration # 464 is done - 1609492611000, 15m, Down, High
#  iteration # 465 is done - 1609492611000, 15m, Down, Close
#  iteration # 466 is done - 1609492611000, 15m, Down, High
#  iteration # 467 is done - 1609492611000, 15m, Down, Close
#  iteration # 468 is done - 1609492611000, 15m, Down, High
#  iteration # 469 is done - 1609492611000, 15m, Down, Close
#  iteration # 470 is done - 1609492611000, 15m, Down, High
#  iteration # 471 is done - 1609492611000, 15m, Down, Close
#  iteration # 472 is done - 1609492611000, 15m, Down, High
#  iteration # 473 is done - 1609492611000, 15m, Down, Close
#  iteration # 474 is done - 1609492611000, 15m, Down, High
#  iteration # 475 is done - 1609492611000, 15m, Down, Close
#  iteration # 476 is done - 1609492611000, 15m, Down, High
#  iteration # 477 is done - 1609492611000, 15m, Down, Close
#  iteration # 478 is done - 1609492611000, 15m, Down, High
#  iteration # 479 is done - 1609492611000, 15m, Down, Close
#  iteration # 480 is done - 1609492611000, 15m, Down, High
#  iteration # 481 is done - 1609492611000, 1h, Any, Close
#  iteration # 482 is done - 1609492611000, 1h, Any, High
#  iteration # 483 is done - 1609492611000, 1h, Any, Close
#  iteration # 484 is done - 1609492611000, 1h, Any, High
#  iteration # 485 is done - 1609492611000, 1h, Any, Close
#  iteration # 486 is done - 1609492611000, 1h, Any, High
#  iteration # 487 is done - 1609492611000, 1h, Any, Close
#  iteration # 488 is done - 1609492611000, 1h, Any, High
#  iteration # 489 is done - 1609492611000, 1h, Any, Close
#  iteration # 490 is done - 1609492611000, 1h, Any, High
#  iteration # 491 is done - 1609492611000, 1h, Any, Close
#  iteration # 492 is done - 1609492611000, 1h, Any, High
#  iteration # 493 is done - 1609492611000, 1h, Any, Close
#  iteration # 494 is done - 1609492611000, 1h, Any, High
#  iteration # 495 is done - 1609492611000, 1h, Any, Close
#  iteration # 496 is done - 1609492611000, 1h, Any, High
#  iteration # 497 is done - 1609492611000, 1h, Any, Close
#  iteration # 498 is done - 1609492611000, 1h, Any, High
#  iteration # 499 is done - 1609492611000, 1h, Any, Close
#  iteration # 500 is done - 1609492611000, 1h, Any, High
#  iteration # 501 is done - 1609492611000, 1h, Any, Close
#  iteration # 502 is done - 1609492611000, 1h, Any, High
#  iteration # 503 is done - 1609492611000, 1h, Any, Close
#  iteration # 504 is done - 1609492611000, 1h, Any, High
#  iteration # 505 is done - 1609492611000, 1h, Any, Close
#  iteration # 506 is done - 1609492611000, 1h, Any, High
#  iteration # 507 is done - 1609492611000, 1h, Any, Close
#  iteration # 508 is done - 1609492611000, 1h, Any, High
#  iteration # 509 is done - 1609492611000, 1h, Any, Close
#  iteration # 510 is done - 1609492611000, 1h, Any, High
#  iteration # 511 is done - 1609492611000, 1h, Any, Close
#  iteration # 512 is done - 1609492611000, 1h, Any, High
#  iteration # 513 is done - 1609492611000, 1h, Up, Close
#  iteration # 514 is done - 1609492611000, 1h, Up, High
#  iteration # 515 is done - 1609492611000, 1h, Up, Close
#  iteration # 516 is done - 1609492611000, 1h, Up, High
#  iteration # 517 is done - 1609492611000, 1h, Up, Close
#  iteration # 518 is done - 1609492611000, 1h, Up, High
#  iteration # 519 is done - 1609492611000, 1h, Up, Close
#  iteration # 520 is done - 1609492611000, 1h, Up, High
#  iteration # 521 is done - 1609492611000, 1h, Up, Close
#  iteration # 522 is done - 1609492611000, 1h, Up, High
#  iteration # 523 is done - 1609492611000, 1h, Up, Close
#  iteration # 524 is done - 1609492611000, 1h, Up, High
#  iteration # 525 is done - 1609492611000, 1h, Up, Close
#  iteration # 526 is done - 1609492611000, 1h, Up, High
#  iteration # 527 is done - 1609492611000, 1h, Up, Close
#  iteration # 528 is done - 1609492611000, 1h, Up, High
#  iteration # 529 is done - 1609492611000, 1h, Up, Close
#  iteration # 530 is done - 1609492611000, 1h, Up, High
#  iteration # 531 is done - 1609492611000, 1h, Up, Close
#  iteration # 532 is done - 1609492611000, 1h, Up, High
#  iteration # 533 is done - 1609492611000, 1h, Up, Close
#  iteration # 534 is done - 1609492611000, 1h, Up, High
#  iteration # 535 is done - 1609492611000, 1h, Up, Close
#  iteration # 536 is done - 1609492611000, 1h, Up, High
#  iteration # 537 is done - 1609492611000, 1h, Up, Close
#  iteration # 538 is done - 1609492611000, 1h, Up, High
#  iteration # 539 is done - 1609492611000, 1h, Up, Close
#  iteration # 540 is done - 1609492611000, 1h, Up, High
#  iteration # 541 is done - 1609492611000, 1h, Up, Close
#  iteration # 542 is done - 1609492611000, 1h, Up, High
#  iteration # 543 is done - 1609492611000, 1h, Up, Close
#  iteration # 544 is done - 1609492611000, 1h, Up, High
#  iteration # 545 is done - 1609492611000, 1h, Down, Close
#  iteration # 546 is done - 1609492611000, 1h, Down, High
#  iteration # 547 is done - 1609492611000, 1h, Down, Close
#  iteration # 548 is done - 1609492611000, 1h, Down, High
#  iteration # 549 is done - 1609492611000, 1h, Down, Close
#  iteration # 550 is done - 1609492611000, 1h, Down, High
#  iteration # 551 is done - 1609492611000, 1h, Down, Close
#  iteration # 552 is done - 1609492611000, 1h, Down, High
#  iteration # 553 is done - 1609492611000, 1h, Down, Close
#  iteration # 554 is done - 1609492611000, 1h, Down, High
#  iteration # 555 is done - 1609492611000, 1h, Down, Close
#  iteration # 556 is done - 1609492611000, 1h, Down, High
#  iteration # 557 is done - 1609492611000, 1h, Down, Close
#  iteration # 558 is done - 1609492611000, 1h, Down, High
#  iteration # 559 is done - 1609492611000, 1h, Down, Close
#  iteration # 560 is done - 1609492611000, 1h, Down, High
#  iteration # 561 is done - 1609492611000, 1h, Down, Close
#  iteration # 562 is done - 1609492611000, 1h, Down, High
#  iteration # 563 is done - 1609492611000, 1h, Down, Close
#  iteration # 564 is done - 1609492611000, 1h, Down, High
#  iteration # 565 is done - 1609492611000, 1h, Down, Close
#  iteration # 566 is done - 1609492611000, 1h, Down, High
#  iteration # 567 is done - 1609492611000, 1h, Down, Close
#  iteration # 568 is done - 1609492611000, 1h, Down, High
#  iteration # 569 is done - 1609492611000, 1h, Down, Close
#  iteration # 570 is done - 1609492611000, 1h, Down, High
#  iteration # 571 is done - 1609492611000, 1h, Down, Close
#  iteration # 572 is done - 1609492611000, 1h, Down, High
#  iteration # 573 is done - 1609492611000, 1h, Down, Close
#  iteration # 574 is done - 1609492611000, 1h, Down, High
#  iteration # 575 is done - 1609492611000, 1h, Down, Close
#  iteration # 576 is done - 1609492611000, 1h, Down, High
# Time taken to execute for loop: 15000.883344173431 seconds
#         start_time interval kd_direction  sl_atr  tp_atr sl_determine  \
# 510  1609492611000       1h          Any       5       6        Close
# 508  1609492611000       1h          Any       5       5        Close
# 318  1641028611000       1h          Any       5       6        Close
# 494  1609492611000       1h          Any       3       6        Close
# 316  1641028611000       1h          Any       5       5        Close
# ..             ...      ...          ...     ...     ...          ...
# 405  1609492611000      15m          Any       4       5         High
# 479  1609492611000      15m         Down       5       6         High
# 475  1609492611000      15m         Down       5       4         High
# 413  1609492611000      15m          Any       5       5         High
# 477  1609492611000      15m         Down       5       5         High
#
#        Profit       Fee  Max_Profit  Max_Loss  Max_Entry  Max_Position  \
# 510  83123.80   4926.70    57823.83  -5812.34        123     270036.19
# 508  76435.93   4930.04    53035.39  -5812.34         88     188319.73
# 318  67534.55   2508.54    36756.01  -2882.36        123     270036.19
# 494  61588.80   4937.46    37032.93  -2849.98         71     170207.20
# 316  57650.73   2513.48    28047.61  -2924.17         88     188319.73
# ..        ...       ...         ...       ...        ...           ...
# 405 -21715.39  19954.21    12759.42  -3919.50         75      86794.18
# 479 -22226.87  10661.90     7085.57  -2664.53         57      66219.65
# 475 -25149.88  10663.36     3171.93  -2664.53         29      33817.41
# 413 -30433.25  19958.57    13394.93  -5003.37         95     111056.36
# 477 -35304.33  10668.44     6512.42  -2664.53         45      53216.34
#
#      Profit_%
# 510   307.82%
# 508   405.88%
# 318   250.09%
# 494   361.85%
# 316   306.13%
# ..        ...
# 405  -250.19%
# 479  -335.65%
# 475  -743.70%
# 413  -274.03%
# 477  -663.41%
#
# [576 rows x 13 columns]

# %%
results_df.to_csv('results_df_008-1.csv')
