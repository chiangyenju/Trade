# %%
import os

# %%
from binance.client import Client
from dotenv import load_dotenv

# Get the path to the current directory
current_directory = os.getcwd()

# Specify the path to the .env file relative to the current directory
dotenv_path = os.path.join(current_directory, '.env')

# Load the environment variables from the .env file
load_dotenv(dotenv_path)

api_key = os.getenv('API_KEY')
api_secret = os.getenv('SECRET_KEY')

client = Client(api_key, api_secret, testnet = False)

# %%
symbols = [symbol['symbol'] for symbol in client.get_exchange_info()['symbols']]
usdtlist = [string for string in symbols if "USDT" in string]

# %%
import asyncio
import aiohttp

# Define the endpoint for fetching trading volume
endpoint = 'https://api.binance.com/api/v3/ticker/24hr'

# Create an empty dictionary to store the trading volumes
trading_volumes = {}

# Function to fetch trading volume for a batch of symbols
async def fetch_trading_volumes(session, symbols):
    tasks = []
    for symbol in symbols:
        params = {
            'symbol': symbol
        }
        task = asyncio.ensure_future(fetch_data(session, params))
        tasks.append(task)

    results = await asyncio.gather(*tasks)
    for symbol, trading_volume in results:
        trading_volumes[symbol] = trading_volume

# Function to make the API request and extract trading volume from the response
async def fetch_data(session, params):
    async with session.get(endpoint, params=params) as response:
        data = await response.json()
        trading_volume = float(data['volume'])
        return params['symbol'], trading_volume

# Split the symbols into batches of 500 (maximum allowed by Binance API)
symbol_batches = [usdtlist[i:i+500] for i in range(0, len(usdtlist), 500)]

# Use the existing event loop
loop = asyncio.get_event_loop()

# Create an instance of aiohttp.ClientSession within the event loop
async with aiohttp.ClientSession(loop=loop) as session:
    tasks = [fetch_trading_volumes(session, symbols) for symbols in symbol_batches]
    await asyncio.gather(*tasks)

# Print the trading volumes
# for symbol, volume in trading_volumes.items():
#     print(f"{symbol}: {volume}")

sorted_symbols = sorted(trading_volumes, key=trading_volumes.get, reverse=True)

for symbol in sorted_symbols:
    print(f"{symbol}: {trading_volumes[symbol]}")
# Out:
# PEPEUSDT: 49876876460234.0
# SHIBUSDT: 3546989647282.0
# BTTCUSDT: 3189954860800.0
# LUNCUSDT: 685814575439.29
# FLOKIUSDT: 204166527569.0
# XECUSDT: 39454226173.0
# EPXUSDT: 17013904611.0
# WINUSDT: 7449644768.0
# XRPDOWNUSDT: 5729575741.84
# LINAUSDT: 3851868212.27
# SPELLUSDT: 3449249031.0
# LEVERUSDT: 3182957345.0
# JASMYUSDT: 2445570384.4
# KEYUSDT: 2304122813.0
# HOTUSDT: 2096520347.0
# RSRUSDT: 2035533375.4
# DENTUSDT: 1566779403.0
# AKROUSDT: 1488796226.0
# DOGEUSDT: 1403652817.0
# AMBUSDT: 1303453977.0
# REEFUSDT: 1229861957.0
# GALAUSDT: 1047567623.0
# CKBUSDT: 785976171.0
# SLPUSDT: 776687734.0
# XRPUSDT: 617775854.0
# ADADOWNUSDT: 606795545.69
# VETUSDT: 446626339.1
# VTHOUSDT: 418211028.0
# ACHUSDT: 383830101.0
# ARPAUSDT: 370533722.8
# TRXUSDT: 365176099.2
# ZILUSDT: 358382193.0
# ONEUSDT: 354470958.9
# USDCUSDT: 349020958.0
# USTCUSDT: 311081212.0
# RENUSDT: 310292512.0
# BUSDUSDT: 296162147.0
# OOKIUSDT: 275099170.0
# XVGUSDT: 266654239.0
# PEOPLEUSDT: 256994875.5
# TUSDUSDT: 235663250.0
# ANKRUSDT: 235034823.3
# ROSEUSDT: 218999607.0
# RVNUSDT: 218583309.2
# AMPUSDT: 217753411.0
# TROYUSDT: 212173078.0
# STMXUSDT: 209229534.0
# SCUSDT: 204046993.0
# IOSTUSDT: 192893217.0
# CFXUSDT: 189318595.0
# DGBUSDT: 181680773.3
# CHZUSDT: 173715263.0
# CELRUSDT: 169050836.3
# BTSUSDT: 167376634.6
# IOTXUSDT: 145123356.0
# FTMUSDT: 141983473.0
# PONDUSDT: 141522428.93
# HBARUSDT: 138623664.0
# TRUUSDT: 134521655.0
# JSTUSDT: 130134874.9
# BTCDOWNUSDT: 129401494.65
# MBLUSDT: 128205147.0
# SANDUSDT: 126406963.0
# ARBUSDT: 115681104.3
# COSUSDT: 115660618.3
# ADAUSDT: 112077428.1
# TVKUSDT: 109150878.0
# TLMUSDT: 108074099.0
# SUIUSDT: 106787753.9
# QIUSDT: 106228439.0
# GRTUSDT: 105243811.0
# USDTTRY: 97273892.0
# SKLUSDT: 95921057.0
# TUSDT: 89818817.8
# IDUSDT: 82278481.0
# SUNUSDT: 77816554.0
# MTLUSDT: 75778356.7
# AGIXUSDT: 74379265.0
# MANAUSDT: 73818963.0
# FETUSDT: 69739113.0
# MDTUSDT: 68403264.4
# ASTRUSDT: 67943434.3
# ALGOUSDT: 67308771.0
# FORUSDT: 66811230.0
# XLMUSDT: 65719762.0
# EDUUSDT: 63068631.0
# MATICUSDT: 62206595.7
# RDNTUSDT: 61899227.0
# IDEXUSDT: 60969979.6
# IRISUSDT: 56464811.7
# GMTUSDT: 53432883.7
# VGXUSDT: 50562232.5
# JOEUSDT: 49979588.96
# ALPHAUSDT: 47781710.0
# CHRUSDT: 45878659.0
# BNBDOWNUSDT: 45125809.28
# OPUSDT: 42266361.96
# NKNUSDT: 41340794.0
# REIUSDT: 40285222.2
# QKCUSDT: 39891552.0
# EURUSDT: 39859930.0
# PERLUSDT: 39431896.1
# ACAUSDT: 38673741.89
# VITEUSDT: 38629673.0
# FUNUSDT: 38226739.0
# BLZUSDT: 36817132.0
# POLYXUSDT: 36170930.5
# VIDTUSDT: 35890227.0
# RNDRUSDT: 34842671.46
# DARUSDT: 33430935.0
# OCEANUSDT: 32789909.0
# COTIUSDT: 30685251.0
# BETAUSDT: 30287501.0
# SXPUSDT: 28645985.4
# CLVUSDT: 28579474.7
# OMUSDT: 27666037.0
# RAYUSDT: 27187383.9
# WOOUSDT: 26894782.4
# DYDXUSDT: 26820668.08
# USDPUSDT: 26681299.0
# DFUSDT: 24997935.0
# LUNAUSDT: 22750489.15
# CTSIUSDT: 21619772.0
# IOTAUSDT: 20500457.0
# KAVAUSDT: 20294268.2
# BUSDTRY: 19671790.0
# DUSKUSDT: 19340806.0
# MAGICUSDT: 19272988.4
# C98USDT: 19268195.0
# 1INCHUSDT: 19232036.8
# BNXUSDT: 19048368.2
# OGNUSDT: 18831386.0
# TFUELUSDT: 18791938.0
# XEMUSDT: 18275172.0
# WAXPUSDT: 18005024.0
# EOSUSDT: 17762221.2
# DOCKUSDT: 17409041.0
# RIFUSDT: 16429839.0
# AUDIOUSDT: 16261259.4
# HIGHUSDT: 16230941.984
# STXUSDT: 16190160.2
# KLAYUSDT: 15695300.1
# ENJUSDT: 15622198.5
# OXTUSDT: 15484251.0
# BAKEUSDT: 15219072.0
# VIBUSDT: 14469565.0
# USDTBRL: 14108585.9
# NEBLUSDT: 13927135.4
# SUPERUSDT: 13921780.0
# FLMUSDT: 13556151.0
# LRCUSDT: 13439394.0
# ONTUSDT: 13421508.0
# CRVUSDT: 13226603.2
# BSWUSDT: 12801843.8
# DODOUSDT: 12587097.3
# DATAUSDT: 12364192.3
# MDXUSDT: 12201869.3
# PHBUSDT: 11957213.0
# ELFUSDT: 11833914.6
# ATAUSDT: 11769547.0
# NEARUSDT: 11712665.4
# ICXUSDT: 11386399.5
# ETHDOWNUSDT: 11166190.95
# STGUSDT: 10807735.6
# COMBOUSDT: 10806855.7
# AERGOUSDT: 10793104.0
# IMXUSDT: 10401341.52
# HFTUSDT: 10290872.9
# STPTUSDT: 10199918.4
# PHAUSDT: 10158701.0
# LDOUSDT: 10148645.47
# MULTIUSDT: 10142054.927
# FLOWUSDT: 10097545.99
# UTKUSDT: 10000858.0
# SNTUSDT: 9765054.0
# APEUSDT: 9745252.47
# LOOMUSDT: 9605393.0
# MINAUSDT: 9168511.1
# USDTBIDR: 8943344.8
# FIOUSDT: 8788423.0
# STEEMUSDT: 8654347.0
# WRXUSDT: 8594106.0
# FILUSDT: 8525032.18
# BATUSDT: 8514622.0
# HOOKUSDT: 8120464.7
# SYSUSDT: 7982213.0
# FLUXUSDT: 7754269.77
# SFPUSDT: 7741229.0
# XRPUPUSDT: 7230839.29
# TOMOUSDT: 7035575.0
# SUSHIUSDT: 7016199.9
# RAREUSDT: 6911288.9
# COCOSUSDT: 6909740.0
# YGGUSDT: 6891818.5
# LITUSDT: 6778239.1
# SYNUSDT: 6757212.0
# CAKEUSDT: 6610718.21
# BELUSDT: 6483120.5
# APTUSDT: 6189004.8
# SOLUSDT: 6139488.44
# OAXUSDT: 6114791.0
# ASTUSDT: 5957634.0
# TWTUSDT: 5833213.0
# GLMRUSDT: 5773958.3
# ADXUSDT: 5735591.0
# MASKUSDT: 5569995.2
# RUNEUSDT: 5380755.3
# DOTUSDT: 5350639.14
# VOXELUSDT: 5255197.2
# THETAUSDT: 5242001.4
# CTXCUSDT: 5167128.0
# ZRXUSDT: 5113859.0
# LTOUSDT: 5099533.0
# HARDUSDT: 5024056.0
# SNXUSDT: 4932067.2
# TKOUSDT: 4923000.8
# NULSUSDT: 4922181.0
# CHESSUSDT: 4679759.0
# KDAUSDT: 4505627.98
# CELOUSDT: 4480553.0
# CVCUSDT: 4454781.0
# LINKUSDT: 4443263.61
# GALUSDT: 4371565.188
# ADAUPUSDT: 4345474.67
# INJUSDT: 4332322.4
# OMGUSDT: 4264240.7
# USDTDAI: 3975441.1
# LQTYUSDT: 3957035.2
# PNTUSDT: 3937957.0
# STORJUSDT: 3839737.0
# WAVESUSDT: 3787826.02
# LOKAUSDT: 3778637.6
# LSKUSDT: 3678825.1
# REQUSDT: 3665817.0
# MBOXUSDT: 3639424.4
# FIDAUSDT: 3621913.7
# AXSUSDT: 3491241.94
# BICOUSDT: 3337668.66
# KNCUSDT: 3161159.3
# DREPUSDT: 3138964.0
# MCUSDT: 3081234.21
# WTCUSDT: 2802477.0
# AVAXUSDT: 2788385.83
# ARDRUSDT: 2629282.0
# ICPUSDT: 2542949.54
# SCRTUSDT: 2540995.8
# BURGERUSDT: 2507895.6
# XTZUSDT: 2453134.7
# HIVEUSDT: 2427888.0
# CITYUSDT: 2398635.17
# ALICEUSDT: 2386221.94
# RADUSDT: 2373770.6
# OSMOUSDT: 2233952.92
# PLAUSDT: 2116148.12
# BANDUSDT: 2060343.9
# CTKUSDT: 2058669.9
# UFTUSDT: 2003362.0
# AGLDUSDT: 1969315.9
# GBPUSDT: 1960109.6
# ATOMUSDT: 1936798.21
# PERPUSDT: 1893755.12
# PROSUSDT: 1887522.0
# FISUSDT: 1846716.0
# DIAUSDT: 1842602.5
# POWRUSDT: 1773613.0
# FRONTUSDT: 1770592.0
# KMDUSDT: 1760177.0
# AVAUSDT: 1605654.0
# BARUSDT: 1577248.56
# CVPUSDT: 1571458.3
# USDTRUB: 1560334.0
# AUDUSDT: 1528057.0
# UNIUSDT: 1520745.41
# RLCUSDT: 1514424.8
# GLMUSDT: 1362887.3
# XNOUSDT: 1335386.0
# LTCUSDT: 1313846.062
# GTCUSDT: 1236140.6
# ALPACAUSDT: 1163704.3
# POLSUSDT: 1162699.4
# HIFIUSDT: 1159108.9
# API3USDT: 1155051.28
# NEXOUSDT: 1138884.74
# PYRUSDT: 1102329.222
# BNBUSDT: 1099990.969
# WANUSDT: 1072325.0
# PUNDIXUSDT: 989487.7
# ORNUSDT: 984289.5
# OGUSDT: 960123.4
# USDTPLN: 939692.0
# MOBUSDT: 867344.38
# UNFIUSDT: 824704.8
# NEOUSDT: 802388.99
# BNTUSDT: 765590.9
# STRAXUSDT: 762301.3
# ETCUSDT: 743128.54
# ERNUSDT: 742025.0
# ANTUSDT: 741876.8
# ONGUSDT: 711653.0
# GHSTUSDT: 710408.7
# UMAUSDT: 666391.7
# FXSUSDT: 638741.2
# ARUSDT: 634088.43
# LAZIOUSDT: 612404.45
# ALPINEUSDT: 589116.61
# SANTOSUSDT: 544957.11
# PORTOUSDT: 544666.08
# ETHUSDT: 544312.1283
# USDTNGN: 525274.8
# DEGOUSDT: 468573.79
# QTUMUSDT: 466486.6
# FIROUSDT: 457184.3
# CVXUSDT: 431107.335
# ENSUSDT: 424625.13
# SSVUSDT: 410987.615
# XVSUSDT: 386708.89
# ASRUSDT: 383874.9
# JUVUSDT: 370742.46
# GNSUSDT: 358777.25
# USDTARS: 335690.0
# USDTUAH: 334437.0
# BONDUSDT: 322839.03
# PSGUSDT: 286156.16
# ACMUSDT: 278839.5
# LPTUSDT: 260352.19
# BADGERUSDT: 257114.41
# ATMUSDT: 242342.48
# EGLDUSDT: 241990.24
# ZENUSDT: 231871.25
# ETHUPUSDT: 229002.23
# BALUSDT: 206632.77
# GASUSDT: 203566.1
# USDTIDRT: 191719.0
# GMXUSDT: 182812.06
# BTCUPUSDT: 176854.99
# TRBUSDT: 151781.01
# WINGUSDT: 144814.09
# AUCTIONUSDT: 133191.56
# ZECUSDT: 126836.009
# AAVEUSDT: 126646.803
# USDTRON: 125367.0
# FORTHUSDT: 115761.58
# DASHUSDT: 110004.604
# MOVRUSDT: 107661.479
# KSMUSDT: 96576.255
# DEXEUSDT: 86728.59
# XMRUSDT: 70648.544
# BTCUSDT: 65820.70011
# COMPUSDT: 60278.933
# BCHUSDT: 58411.093
# PROMUSDT: 55226.2
# QNTUSDT: 44201.516
# ILVUSDT: 43130.407
# NMRUSDT: 41734.51
# ALCXUSDT: 38327.8732
# BNBUPUSDT: 37553.46
# AUTOUSDT: 28053.064
# DCRUSDT: 21520.977
# QUICKUSDT: 14260.799
# FARMUSDT: 11602.393
# RPLUSDT: 11085.76
# MLNUSDT: 10818.555
# KP3RUSDT: 8748.75
# MKRUSDT: 6395.4157
# WNXMUSDT: 5965.48
# YFIIUSDT: 2964.7995
# PAXGUSDT: 2844.3824
# BETHUSDT: 1507.2229
# GNOUSDT: 1267.701
# YFIUSDT: 476.85993
# BIFIUSDT: 395.406
# WBTCUSDT: 4.57381
# BCCUSDT: 0.0
# VENUSDT: 0.0
# PAXUSDT: 0.0
# BCHABCUSDT: 0.0
# BCHSVUSDT: 0.0
# BTTUSDT: 0.0
# USDSUSDT: 0.0
# NANOUSDT: 0.0
# MITHUSDT: 0.0
# USDSBUSDT: 0.0
# GTOUSDT: 0.0
# ERDUSDT: 0.0
# NPXSUSDT: 0.0
# MFTUSDT: 0.0
# STORMUSDT: 0.0
# BEAMUSDT: 0.0
# HCUSDT: 0.0
# MCOUSDT: 0.0
# FTTUSDT: 0.0
# BULLUSDT: 0.0
# BEARUSDT: 0.0
# ETHBULLUSDT: 0.0
# ETHBEARUSDT: 0.0
# TCTUSDT: 0.0
# EOSBULLUSDT: 0.0
# EOSBEARUSDT: 0.0
# XRPBULLUSDT: 0.0
# XRPBEARUSDT: 0.0
# STRATUSDT: 0.0
# AIONUSDT: 0.0
# BNBBULLUSDT: 0.0
# BNBBEARUSDT: 0.0
# USDTZAR: 0.0
# XZCUSDT: 0.0
# GXSUSDT: 0.0
# LENDUSDT: 0.0
# REPUSDT: 0.0
# BKRWUSDT: 0.0
# LINKUPUSDT: 0.0
# LINKDOWNUSDT: 0.0
# DAIUSDT: 0.0
# XTZUPUSDT: 0.0
# XTZDOWNUSDT: 0.0
# USDTBKRW: 0.0
# SRMUSDT: 0.0
# BZRXUSDT: 0.0
# EOSUPUSDT: 0.0
# EOSDOWNUSDT: 0.0
# TRXUPUSDT: 0.0
# TRXDOWNUSDT: 0.0
# DOTUPUSDT: 0.0
# DOTDOWNUSDT: 0.0
# LTCUPUSDT: 0.0
# LTCDOWNUSDT: 0.0
# NBSUSDT: 0.0
# HNTUSDT: 0.0
# UNIUPUSDT: 0.0
# UNIDOWNUSDT: 0.0
# SXPUPUSDT: 0.0
# SXPDOWNUSDT: 0.0
# FILUPUSDT: 0.0
# FILDOWNUSDT: 0.0
# YFIUPUSDT: 0.0
# YFIDOWNUSDT: 0.0
# BCHUPUSDT: 0.0
# BCHDOWNUSDT: 0.0
# DNTUSDT: 0.0
# AAVEUPUSDT: 0.0
# AAVEDOWNUSDT: 0.0
# SUSDUSDT: 0.0
# SUSHIUPUSDT: 0.0
# SUSHIDOWNUSDT: 0.0
# XLMUPUSDT: 0.0
# XLMDOWNUSDT: 0.0
# USDTBVND: 0.0
# BTCSTUSDT: 0.0
# RAMPUSDT: 0.0
# EPSUSDT: 0.0
# 1INCHUPUSDT: 0.0
# 1INCHDOWNUSDT: 0.0
# BTGUSDT: 0.0
# MIRUSDT: 0.0
# NUUSDT: 0.0
# TORNUSDT: 0.0
# KEEPUSDT: 0.0
# TRIBEUSDT: 0.0
# POLYUSDT: 0.0
# RGTUSDT: 0.0
# ANYUSDT: 0.0
# USTUSDT: 0.0
# ANCUSDT: 0.0
